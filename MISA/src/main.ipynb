# %% [markdown]
# ## Config

# %%
import os
import argparse
from datetime import datetime
from collections import defaultdict
from datetime import datetime
from pathlib import Path
import pprint
from torch import optim
import torch.nn as nn

# %%
# path to a pretrained word embedding file
# word_emb_path = '/mnt/soyeon/workspace/glove.840B.300d.txt'
word_emb_path = '/home/ubuntu/soyeon/glove.840B.300d.txt'
assert(word_emb_path is not None)


# username = Path.home().name
# project_dir = Path(__file__).resolve().parent.parent
# sdk_dir = project_dir.joinpath('CMU-MultimodalSDK')
# data_dir = project_dir.joinpath('datasets')

sdk_dir = Path('/home/ubuntu/soyeon/CMU-MultimodalSDK')
data_dir = Path('/home/ubuntu/soyeon/MSIR/datasets')
data_dict = {'mosi': data_dir.joinpath('MOSI'), 'mosei': data_dir.joinpath(
    'MOSEI'), 'ur_funny': data_dir.joinpath('UR_FUNNY')}
optimizer_dict = {'RMSprop': optim.RMSprop, 'Adam': optim.Adam}
activation_dict = {'elu': nn.ELU, "hardshrink": nn.Hardshrink, "hardtanh": nn.Hardtanh,
                   "leakyrelu": nn.LeakyReLU, "prelu": nn.PReLU, "relu": nn.ReLU, "rrelu": nn.RReLU,
                   "tanh": nn.Tanh}

# %%
def str2bool(v):
    """string to boolean"""
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise argparse.ArgumentTypeError('Boolean value expected.')


class Config(object):
    def __init__(self, **kwargs):
        """Configuration Class: set kwargs as class attributes with setattr"""
        if kwargs is not None:
            for key, value in kwargs.items():
                if key == 'optimizer':
                    value = optimizer_dict[value]
                if key == 'activation':
                    value = activation_dict[value]
                setattr(self, key, value)

        # Dataset directory: ex) ./datasets/cornell/
        self.dataset_dir = data_dict[self.data.lower()]
        self.sdk_dir = sdk_dir
        # Glove path
        self.word_emb_path = word_emb_path

        # Data Split ex) 'train', 'valid', 'test'
        # self.data_dir = self.dataset_dir.joinpath(self.mode)
        self.data_dir = self.dataset_dir

    def __str__(self):
        """Pretty-print configurations in alphabetical order"""
        config_str = 'Configurations\n'
        config_str += pprint.pformat(self.__dict__)
        return config_str

# %%
import easydict

def get_config(parse=True, **optional_kwargs):
    time_now = datetime.now().strftime('%Y-%m-%d_%H:%M:%S')
    kwargs = easydict.EasyDict({
        # Mode
        'mode': 'train',
        'runs': 5,

        # Bert
        'use_bert': True,
        'use_cmd_sim': True,

        # Train
        'name': f"{time_now}",
        'num_classes': 0,
        'batch_size': 128,
        'eval_batch_size': 10,
        'n_epoch': 500,
        'patience': 6,
        
        'diff_weight': 0.3,
        'sim_weight': 1.0,
        'sp_weight': 0.0,
        'recon_weight': 1.0,

        'learning_rate': 1e-4,
        'optimizer': 'Adam',
        'clip': 1.0,

        'rnncell': 'lstm',
        'embedding_size': 300,
        'hidden_size': 128,
        'dropout': 0.5,
        'reverse_grad_weight': 1.0,
        
        # Selection activation from 'elu', 'hardshrink', 'hardtanh', 'leakyrelu', 'prelu', 'relu', 'rrelu', 'tanh'
        'activation': 'relu',

        # Model
        'model': 'MISA',
        
        # Data
        'data': 'mosi'
    })

    if kwargs.data == "mosi":
        kwargs.num_classes = 1
        kwargs.batch_size = 64
    elif kwargs.data == "mosei":
        kwargs.num_classes = 1
        kwargs.batch_size = 16
    elif kwargs.data == "ur_funny":
        kwargs.num_classes = 2
        kwargs.batch_size = 32
    else:
        print("No dataset mentioned")
        exit()

    return Config(**kwargs)

# %% [markdown]
# ## Train

# %%
import os
import pickle
from pyexpat import model
import numpy as np
from random import random

# from config import get_config, activation_dict
from data_loader import get_loader
from solver import Solver
from test_instance import TestMOSI, TestMOSEI

import torch
import torch.nn as nn
from torch.nn import functional as F
# Out:
# /home/ubuntu/anaconda3/envs/pytorch1.7.1_p37/lib/python3.7/site-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '
# loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /home/ubuntu/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/ubuntu/.cache/huggingface/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /home/ubuntu/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /home/ubuntu/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/ubuntu/.cache/huggingface/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /home/ubuntu/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /home/ubuntu/.cache/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/ubuntu/.cache/huggingface/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /home/ubuntu/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %%
# Setting random seed
random_name = str(random())
random_seed = 336   
torch.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

# Setting the config for each stage
train_config = get_config(mode='train')
dev_config = get_config(mode='dev')
test_config = get_config(mode='test')


print(train_config)
# Out:
# Configurations
# {'activation': <class 'torch.nn.modules.activation.ReLU'>,
#  'batch_size': 64,
#  'clip': 1.0,
#  'data': 'mosi',
#  'data_dir': PosixPath('/home/ubuntu/soyeon/MSIR/datasets/MOSI'),
#  'dataset_dir': PosixPath('/home/ubuntu/soyeon/MSIR/datasets/MOSI'),
#  'diff_weight': 0.3,
#  'dropout': 0.5,
#  'embedding_size': 300,
#  'eval_batch_size': 10,
#  'hidden_size': 128,
#  'learning_rate': 0.0001,
#  'mode': 'train',
#  'model': 'MISA',
#  'n_epoch': 500,
#  'name': '2022-06-06_23:13:46',
#  'num_classes': 1,
#  'optimizer': <class 'torch.optim.adam.Adam'>,
#  'patience': 6,
#  'recon_weight': 1.0,
#  'reverse_grad_weight': 1.0,
#  'rnncell': 'lstm',
#  'runs': 5,
#  'sdk_dir': PosixPath('/home/ubuntu/soyeon/CMU-MultimodalSDK'),
#  'sim_weight': 1.0,
#  'sp_weight': 0.0,
#  'use_bert': True,
#  'use_cmd_sim': True,
#  'word_emb_path': '/home/ubuntu/soyeon/glove.840B.300d.txt'}

# %%
# Creating pytorch dataloaders
train_data_loader = get_loader(train_config, shuffle = True)
dev_data_loader = get_loader(dev_config, shuffle = False)
test_data_loader = get_loader(test_config, shuffle = False)
# Out:
# train
# train
# train

# %%
# Solver is a wrapper for model traiing and testing
solver = Solver
solver = solver(train_config, dev_config, test_config, train_data_loader, dev_data_loader, test_data_loader, is_train=True)

# %%
model = solver.build()
# Out:
# Build Graph
# loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /home/ubuntu/.cache/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_hidden_states": true,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.18.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /home/ubuntu/.cache/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.
# 	bertmodel.embeddings.word_embeddings.weight True
# 	bertmodel.embeddings.position_embeddings.weight True
# 	bertmodel.embeddings.token_type_embeddings.weight True
# 	bertmodel.embeddings.LayerNorm.weight True
# 	bertmodel.embeddings.LayerNorm.bias True
# 	bertmodel.encoder.layer.0.attention.self.query.weight True
# 	bertmodel.encoder.layer.0.attention.self.query.bias True
# 	bertmodel.encoder.layer.0.attention.self.key.weight True
# 	bertmodel.encoder.layer.0.attention.self.key.bias True
# 	bertmodel.encoder.layer.0.attention.self.value.weight True
# 	bertmodel.encoder.layer.0.attention.self.value.bias True
# 	bertmodel.encoder.layer.0.attention.output.dense.weight True
# 	bertmodel.encoder.layer.0.attention.output.dense.bias True
# 	bertmodel.encoder.layer.0.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.0.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.0.intermediate.dense.weight True
# 	bertmodel.encoder.layer.0.intermediate.dense.bias True
# 	bertmodel.encoder.layer.0.output.dense.weight True
# 	bertmodel.encoder.layer.0.output.dense.bias True
# 	bertmodel.encoder.layer.0.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.0.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.1.attention.self.query.weight True
# 	bertmodel.encoder.layer.1.attention.self.query.bias True
# 	bertmodel.encoder.layer.1.attention.self.key.weight True
# 	bertmodel.encoder.layer.1.attention.self.key.bias True
# 	bertmodel.encoder.layer.1.attention.self.value.weight True
# 	bertmodel.encoder.layer.1.attention.self.value.bias True
# 	bertmodel.encoder.layer.1.attention.output.dense.weight True
# 	bertmodel.encoder.layer.1.attention.output.dense.bias True
# 	bertmodel.encoder.layer.1.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.1.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.1.intermediate.dense.weight True
# 	bertmodel.encoder.layer.1.intermediate.dense.bias True
# 	bertmodel.encoder.layer.1.output.dense.weight True
# 	bertmodel.encoder.layer.1.output.dense.bias True
# 	bertmodel.encoder.layer.1.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.1.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.2.attention.self.query.weight True
# 	bertmodel.encoder.layer.2.attention.self.query.bias True
# 	bertmodel.encoder.layer.2.attention.self.key.weight True
# 	bertmodel.encoder.layer.2.attention.self.key.bias True
# 	bertmodel.encoder.layer.2.attention.self.value.weight True
# 	bertmodel.encoder.layer.2.attention.self.value.bias True
# 	bertmodel.encoder.layer.2.attention.output.dense.weight True
# 	bertmodel.encoder.layer.2.attention.output.dense.bias True
# 	bertmodel.encoder.layer.2.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.2.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.2.intermediate.dense.weight True
# 	bertmodel.encoder.layer.2.intermediate.dense.bias True
# 	bertmodel.encoder.layer.2.output.dense.weight True
# 	bertmodel.encoder.layer.2.output.dense.bias True
# 	bertmodel.encoder.layer.2.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.2.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.3.attention.self.query.weight True
# 	bertmodel.encoder.layer.3.attention.self.query.bias True
# 	bertmodel.encoder.layer.3.attention.self.key.weight True
# 	bertmodel.encoder.layer.3.attention.self.key.bias True
# 	bertmodel.encoder.layer.3.attention.self.value.weight True
# 	bertmodel.encoder.layer.3.attention.self.value.bias True
# 	bertmodel.encoder.layer.3.attention.output.dense.weight True
# 	bertmodel.encoder.layer.3.attention.output.dense.bias True
# 	bertmodel.encoder.layer.3.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.3.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.3.intermediate.dense.weight True
# 	bertmodel.encoder.layer.3.intermediate.dense.bias True
# 	bertmodel.encoder.layer.3.output.dense.weight True
# 	bertmodel.encoder.layer.3.output.dense.bias True
# 	bertmodel.encoder.layer.3.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.3.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.4.attention.self.query.weight True
# 	bertmodel.encoder.layer.4.attention.self.query.bias True
# 	bertmodel.encoder.layer.4.attention.self.key.weight True
# 	bertmodel.encoder.layer.4.attention.self.key.bias True
# 	bertmodel.encoder.layer.4.attention.self.value.weight True
# 	bertmodel.encoder.layer.4.attention.self.value.bias True
# 	bertmodel.encoder.layer.4.attention.output.dense.weight True
# 	bertmodel.encoder.layer.4.attention.output.dense.bias True
# 	bertmodel.encoder.layer.4.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.4.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.4.intermediate.dense.weight True
# 	bertmodel.encoder.layer.4.intermediate.dense.bias True
# 	bertmodel.encoder.layer.4.output.dense.weight True
# 	bertmodel.encoder.layer.4.output.dense.bias True
# 	bertmodel.encoder.layer.4.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.4.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.5.attention.self.query.weight True
# 	bertmodel.encoder.layer.5.attention.self.query.bias True
# 	bertmodel.encoder.layer.5.attention.self.key.weight True
# 	bertmodel.encoder.layer.5.attention.self.key.bias True
# 	bertmodel.encoder.layer.5.attention.self.value.weight True
# 	bertmodel.encoder.layer.5.attention.self.value.bias True
# 	bertmodel.encoder.layer.5.attention.output.dense.weight True
# 	bertmodel.encoder.layer.5.attention.output.dense.bias True
# 	bertmodel.encoder.layer.5.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.5.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.5.intermediate.dense.weight True
# 	bertmodel.encoder.layer.5.intermediate.dense.bias True
# 	bertmodel.encoder.layer.5.output.dense.weight True
# 	bertmodel.encoder.layer.5.output.dense.bias True
# 	bertmodel.encoder.layer.5.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.5.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.6.attention.self.query.weight True
# 	bertmodel.encoder.layer.6.attention.self.query.bias True
# 	bertmodel.encoder.layer.6.attention.self.key.weight True
# 	bertmodel.encoder.layer.6.attention.self.key.bias True
# 	bertmodel.encoder.layer.6.attention.self.value.weight True
# 	bertmodel.encoder.layer.6.attention.self.value.bias True
# 	bertmodel.encoder.layer.6.attention.output.dense.weight True
# 	bertmodel.encoder.layer.6.attention.output.dense.bias True
# 	bertmodel.encoder.layer.6.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.6.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.6.intermediate.dense.weight True
# 	bertmodel.encoder.layer.6.intermediate.dense.bias True
# 	bertmodel.encoder.layer.6.output.dense.weight True
# 	bertmodel.encoder.layer.6.output.dense.bias True
# 	bertmodel.encoder.layer.6.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.6.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.7.attention.self.query.weight True
# 	bertmodel.encoder.layer.7.attention.self.query.bias True
# 	bertmodel.encoder.layer.7.attention.self.key.weight True
# 	bertmodel.encoder.layer.7.attention.self.key.bias True
# 	bertmodel.encoder.layer.7.attention.self.value.weight True
# 	bertmodel.encoder.layer.7.attention.self.value.bias True
# 	bertmodel.encoder.layer.7.attention.output.dense.weight True
# 	bertmodel.encoder.layer.7.attention.output.dense.bias True
# 	bertmodel.encoder.layer.7.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.7.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.7.intermediate.dense.weight True
# 	bertmodel.encoder.layer.7.intermediate.dense.bias True
# 	bertmodel.encoder.layer.7.output.dense.weight True
# 	bertmodel.encoder.layer.7.output.dense.bias True
# 	bertmodel.encoder.layer.7.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.7.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.8.attention.self.query.weight True
# 	bertmodel.encoder.layer.8.attention.self.query.bias True
# 	bertmodel.encoder.layer.8.attention.self.key.weight True
# 	bertmodel.encoder.layer.8.attention.self.key.bias True
# 	bertmodel.encoder.layer.8.attention.self.value.weight True
# 	bertmodel.encoder.layer.8.attention.self.value.bias True
# 	bertmodel.encoder.layer.8.attention.output.dense.weight True
# 	bertmodel.encoder.layer.8.attention.output.dense.bias True
# 	bertmodel.encoder.layer.8.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.8.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.8.intermediate.dense.weight True
# 	bertmodel.encoder.layer.8.intermediate.dense.bias True
# 	bertmodel.encoder.layer.8.output.dense.weight True
# 	bertmodel.encoder.layer.8.output.dense.bias True
# 	bertmodel.encoder.layer.8.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.8.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.9.attention.self.query.weight True
# 	bertmodel.encoder.layer.9.attention.self.query.bias True
# 	bertmodel.encoder.layer.9.attention.self.key.weight True
# 	bertmodel.encoder.layer.9.attention.self.key.bias True
# 	bertmodel.encoder.layer.9.attention.self.value.weight True
# 	bertmodel.encoder.layer.9.attention.self.value.bias True
# 	bertmodel.encoder.layer.9.attention.output.dense.weight True
# 	bertmodel.encoder.layer.9.attention.output.dense.bias True
# 	bertmodel.encoder.layer.9.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.9.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.9.intermediate.dense.weight True
# 	bertmodel.encoder.layer.9.intermediate.dense.bias True
# 	bertmodel.encoder.layer.9.output.dense.weight True
# 	bertmodel.encoder.layer.9.output.dense.bias True
# 	bertmodel.encoder.layer.9.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.9.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.10.attention.self.query.weight True
# 	bertmodel.encoder.layer.10.attention.self.query.bias True
# 	bertmodel.encoder.layer.10.attention.self.key.weight True
# 	bertmodel.encoder.layer.10.attention.self.key.bias True
# 	bertmodel.encoder.layer.10.attention.self.value.weight True
# 	bertmodel.encoder.layer.10.attention.self.value.bias True
# 	bertmodel.encoder.layer.10.attention.output.dense.weight True
# 	bertmodel.encoder.layer.10.attention.output.dense.bias True
# 	bertmodel.encoder.layer.10.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.10.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.10.intermediate.dense.weight True
# 	bertmodel.encoder.layer.10.intermediate.dense.bias True
# 	bertmodel.encoder.layer.10.output.dense.weight True
# 	bertmodel.encoder.layer.10.output.dense.bias True
# 	bertmodel.encoder.layer.10.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.10.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.11.attention.self.query.weight True
# 	bertmodel.encoder.layer.11.attention.self.query.bias True
# 	bertmodel.encoder.layer.11.attention.self.key.weight True
# 	bertmodel.encoder.layer.11.attention.self.key.bias True
# 	bertmodel.encoder.layer.11.attention.self.value.weight True
# 	bertmodel.encoder.layer.11.attention.self.value.bias True
# 	bertmodel.encoder.layer.11.attention.output.dense.weight True
# 	bertmodel.encoder.layer.11.attention.output.dense.bias True
# 	bertmodel.encoder.layer.11.attention.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.11.attention.output.LayerNorm.bias True
# 	bertmodel.encoder.layer.11.intermediate.dense.weight True
# 	bertmodel.encoder.layer.11.intermediate.dense.bias True
# 	bertmodel.encoder.layer.11.output.dense.weight True
# 	bertmodel.encoder.layer.11.output.dense.bias True
# 	bertmodel.encoder.layer.11.output.LayerNorm.weight True
# 	bertmodel.encoder.layer.11.output.LayerNorm.bias True
# 	bertmodel.pooler.dense.weight True
# 	bertmodel.pooler.dense.bias True
# 	vrnn1.weight_ih_l0 True
# 	vrnn1.weight_hh_l0 True
# 	vrnn1.bias_ih_l0 True
# 	vrnn1.bias_hh_l0 True
# 	vrnn1.weight_ih_l0_reverse True
# 	vrnn1.weight_hh_l0_reverse True
# 	vrnn1.bias_ih_l0_reverse True
# 	vrnn1.bias_hh_l0_reverse True
# 	vrnn2.weight_ih_l0 True
# 	vrnn2.weight_hh_l0 True
# 	vrnn2.bias_ih_l0 True
# 	vrnn2.bias_hh_l0 True
# 	vrnn2.weight_ih_l0_reverse True
# 	vrnn2.weight_hh_l0_reverse True
# 	vrnn2.bias_ih_l0_reverse True
# 	vrnn2.bias_hh_l0_reverse True
# 	arnn1.weight_ih_l0 True
# 	arnn1.weight_hh_l0 True
# 	arnn1.bias_ih_l0 True
# 	arnn1.bias_hh_l0 True
# 	arnn1.weight_ih_l0_reverse True
# 	arnn1.weight_hh_l0_reverse True
# 	arnn1.bias_ih_l0_reverse True
# 	arnn1.bias_hh_l0_reverse True
# 	arnn2.weight_ih_l0 True
# 	arnn2.weight_hh_l0 True
# 	arnn2.bias_ih_l0 True
# 	arnn2.bias_hh_l0 True
# 	arnn2.weight_ih_l0_reverse True
# 	arnn2.weight_hh_l0_reverse True
# 	arnn2.bias_ih_l0_reverse True
# 	arnn2.bias_hh_l0_reverse True
# 	project_t.project_t.weight True
# 	project_t.project_t.bias True
# 	project_t.project_t_layer_norm.weight True
# 	project_t.project_t_layer_norm.bias True
# 	project_v.project_v.weight True
# 	project_v.project_v.bias True
# 	project_v.project_v_layer_norm.weight True
# 	project_v.project_v_layer_norm.bias True
# 	project_a.project_a.weight True
# 	project_a.project_a.bias True
# 	project_a.project_a_layer_norm.weight True
# 	project_a.project_a_layer_norm.bias True
# 	private_t.private_t_1.weight True
# 	private_t.private_t_1.bias True
# 	private_v.private_v_1.weight True
# 	private_v.private_v_1.bias True
# 	private_a.private_a_3.weight True
# 	private_a.private_a_3.bias True
# 	shared.shared_1.weight True
# 	shared.shared_1.bias True
# 	recon_t.recon_t_1.weight True
# 	recon_t.recon_t_1.bias True
# 	recon_v.recon_v_1.weight True
# 	recon_v.recon_v_1.bias True
# 	recon_a.recon_a_1.weight True
# 	recon_a.recon_a_1.bias True
# 	sp_discriminator.sp_discriminator_layer_1.weight True
# 	sp_discriminator.sp_discriminator_layer_1.bias True
# 	fusion.fusion_layer_1.weight True
# 	fusion.fusion_layer_1.bias True
# 	fusion.fusion_layer_3.weight True
# 	fusion.fusion_layer_3.bias True
# 	tlayer_norm.weight True
# 	tlayer_norm.bias True
# 	vlayer_norm.weight True
# 	vlayer_norm.bias True
# 	alayer_norm.weight True
# 	alayer_norm.bias True
# 	transformer_encoder.layers.0.self_attn.in_proj_weight True
# 	transformer_encoder.layers.0.self_attn.in_proj_bias True
# 	transformer_encoder.layers.0.self_attn.out_proj.weight True
# 	transformer_encoder.layers.0.self_attn.out_proj.bias True
# 	transformer_encoder.layers.0.linear1.weight True
# 	transformer_encoder.layers.0.linear1.bias True
# 	transformer_encoder.layers.0.linear2.weight True
# 	transformer_encoder.layers.0.linear2.bias True
# 	transformer_encoder.layers.0.norm1.weight True
# 	transformer_encoder.layers.0.norm1.bias True
# 	transformer_encoder.layers.0.norm2.weight True
# 	transformer_encoder.layers.0.norm2.bias True
# Done! It took 8.5 secs

# %%
solver.train()
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Training Start!
# /home/ubuntu/anaconda3/envs/pytorch1.7.1_p37/lib/python3.7/site-packages/transformers/tokenization_utils_base.py:2269: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /home/ubuntu/anaconda3/envs/pytorch1.7.1_p37/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /home/ubuntu/anaconda3/envs/pytorch1.7.1_p37/lib/python3.7/site-packages/torch/nn/modules/loss.py:446: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([3, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Training loss: 4.3373
# Current patience: 6, current trial: 1.
# Found new best model on dev set!
# Training loss: 3.7146
# Current patience: 6, current trial: 1.
# Training loss: 3.4759
# Current patience: 5, current trial: 1.
# Training loss: 3.4116
# Current patience: 4, current trial: 1.
# Training loss: 3.1194
# Current patience: 3, current trial: 1.
# Training loss: 3.0754
# Current patience: 2, current trial: 1.
# Training loss: 3.0093
# Current patience: 1, current trial: 1.
# Training loss: 2.8166
# Current patience: 0, current trial: 1.
# Running out of patience, loading previous best model.
# Current learning rate: 5e-05
# Running out of patience, early stopping.
# mae:  1.3133608
# corr:  0.11986355497841569
# mult_acc:  0.19251753702260327
# Classification Report (pos/neg) :
#               precision    recall  f1-score   support
#
#        False    0.00000   0.00000   0.00000       552
#         True    0.55122   1.00000   0.71069       678
#
#     accuracy                        0.55122      1230
#    macro avg    0.27561   0.50000   0.35535      1230
# weighted avg    0.30384   0.55122   0.39175      1230
#
# Accuracy (pos/neg)  0.551219512195122
# Classification Report (non-neg/neg) :
#               precision    recall  f1-score   support
#
#        False    0.00000   0.00000   0.00000       552
#         True    0.56976   1.00000   0.72592       731
#
#     accuracy                        0.56976      1283
#    macro avg    0.28488   0.50000   0.36296      1283
# weighted avg    0.32462   0.56976   0.41360      1283
#
# Accuracy (non-neg/neg)  0.5697583787996883
# Done! It took 4.9e+01 secs
# /home/ubuntu/anaconda3/envs/pytorch1.7.1_p37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
torch.save(model.state_dict(), "./saved_models_MISA_mosi.pt")

# %%
model.load_state_dict(torch.load("./saved_models_MISA_mosi.pt"))
model.eval()
# Out:
# MISA(
#   (activation): ReLU()
#   (tanh): Tanh()
#   (bertmodel): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (vrnn1): LSTM(47, 47, bidirectional=True)
#   (vrnn2): LSTM(94, 47, bidirectional=True)
#   (arnn1): LSTM(74, 74, bidirectional=True)
#   (arnn2): LSTM(148, 74, bidirectional=True)
#   (project_t): Sequential(
#     (project_t): Linear(in_features=768, out_features=128, bias=True)
#     (project_t_activation): ReLU()
#     (project_t_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (project_v): Sequential(
#     (project_v): Linear(in_features=188, out_features=128, bias=True)
#     (project_v_activation): ReLU()
#     (project_v_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (project_a): Sequential(
#     (project_a): Linear(in_features=296, out_features=128, bias=True)
#     (project_a_activation): ReLU()
#     (project_a_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (private_t): Sequential(
#     (private_t_1): Linear(in_features=128, out_features=128, bias=True)
#     (private_t_activation_1): Sigmoid()
#   )
#   (private_v): Sequential(
#     (private_v_1): Linear(in_features=128, out_features=128, bias=True)
#     (private_v_activation_1): Sigmoid()
#   )
#   (private_a): Sequential(
#     (private_a_3): Linear(in_features=128, out_features=128, bias=True)
#     (private_a_activation_3): Sigmoid()
#   )
#   (shared): Sequential(
#     (shared_1): Linear(in_features=128, out_features=128, bias=True)
#     (shared_activation_1): Sigmoid()
#   )
#   (recon_t): Sequential(
#     (recon_t_1): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (recon_v): Sequential(
#     (recon_v_1): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (recon_a): Sequential(
#     (recon_a_1): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (sp_discriminator): Sequential(
#     (sp_discriminator_layer_1): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (fusion): Sequential(
#     (fusion_layer_1): Linear(in_features=768, out_features=384, bias=True)
#     (fusion_layer_1_dropout): Dropout(p=0.5, inplace=False)
#     (fusion_layer_1_activation): ReLU()
#     (fusion_layer_3): Linear(in_features=384, out_features=1, bias=True)
#   )
#   (tlayer_norm): LayerNorm((600,), eps=1e-05, elementwise_affine=True)
#   (vlayer_norm): LayerNorm((94,), eps=1e-05, elementwise_affine=True)
#   (alayer_norm): LayerNorm((148,), eps=1e-05, elementwise_affine=True)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
# )

# %%
# Make test result file by instance
tester = TestMOSI
tester = tester(model)
segment_list, preds, preds_2, preds_7 = tester.start()
# Out:
#   0%|          | 0/69 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/ubuntu/anaconda3/envs/pytorch1.7.1_p37/lib/python3.7/site-packages/transformers/tokenization_utils_base.py:2269: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# 100%|██████████| 69/69 [00:02<00:00, 23.30it/s]
# 0 th data
# c7UH_rxdZv4[0]
# 0.3923420011997223
# positive
# Neutral
# 1 th data
# c7UH_rxdZv4[1]
# 0.2903745770454407
# positive
# Neutral
# 2 th data
# c7UH_rxdZv4[2]
# 0.19309017062187195
# positive
# Neutral
# 3 th data
# c7UH_rxdZv4[3]
# 0.26682808995246887
# positive
# Neutral
# 4 th data
# c7UH_rxdZv4[4]
# 0.2718200981616974
# positive
# Neutral
# 5 th data
# c7UH_rxdZv4[5]
# 0.2544107735157013
# positive
# Neutral
# 6 th data
# c7UH_rxdZv4[6]
# 0.16008231043815613
# positive
# Neutral
# 7 th data
# c7UH_rxdZv4[7]
# 0.29097780585289
# positive
# Neutral
# 8 th data
# c7UH_rxdZv4[8]
# 0.21132530272006989
# positive
# Neutral
# 9 th data
# c7UH_rxdZv4[9]
# 0.2739690840244293
# positive
# Neutral
# 10 th data
# c7UH_rxdZv4[10]
# 0.24210606515407562
# positive
# Neutral
# 11 th data
# c7UH_rxdZv4[11]
# 0.2579873204231262
# positive
# Neutral
# 12 th data
# c7UH_rxdZv4[12]
# 0.25383099913597107
# positive
# Neutral
# 13 th data
# c7UH_rxdZv4[13]
# 0.24042315781116486
# positive
# Neutral
# 14 th data
# c7UH_rxdZv4[14]
# 0.2915196120738983
# positive
# Neutral
# 15 th data
# c7UH_rxdZv4[15]
# 0.24061758816242218
# positive
# Neutral
# 16 th data
# c7UH_rxdZv4[16]
# 0.2851758301258087
# positive
# Neutral
# 17 th data
# c7UH_rxdZv4[17]
# 0.16746321320533752
# positive
# Neutral
# 18 th data
# c7UH_rxdZv4[18]
# 0.30240991711616516
# positive
# Neutral
# 19 th data
# c7UH_rxdZv4[19]
# 0.39809808135032654
# positive
# Neutral
# 20 th data
# c7UH_rxdZv4[20]
# 0.2889544665813446
# positive
# Neutral
# 21 th data
# c7UH_rxdZv4[21]
# 0.1962002068758011
# positive
# Neutral
# 22 th data
# c7UH_rxdZv4[22]
# 0.3363937437534332
# positive
# Neutral
# 23 th data
# c7UH_rxdZv4[23]
# 0.1632203608751297
# positive
# Neutral
# 24 th data
# c7UH_rxdZv4[24]
# 0.2833019196987152
# positive
# Neutral
# 25 th data
# c7UH_rxdZv4[25]
# 0.2990058362483978
# positive
# Neutral
# 26 th data
# c7UH_rxdZv4[26]
# 0.14536523818969727
# positive
# Neutral
# 27 th data
# c7UH_rxdZv4[27]
# 0.3553224503993988
# positive
# Neutral
# 28 th data
# c7UH_rxdZv4[28]
# 0.27100425958633423
# positive
# Neutral
# 29 th data
# c7UH_rxdZv4[29]
# 0.20675574243068695
# positive
# Neutral
# 30 th data
# c7UH_rxdZv4[30]
# 0.3200872838497162
# positive
# Neutral
# 31 th data
# c7UH_rxdZv4[31]
# 0.21747462451457977
# positive
# Neutral
# 32 th data
# c7UH_rxdZv4[32]
# 0.2676334083080292
# positive
# Neutral
# 33 th data
# cM3Yna7AavY[0]
# 0.24636386334896088
# positive
# Neutral
# 34 th data
# cM3Yna7AavY[1]
# 0.22851385176181793
# positive
# Neutral
# 35 th data
# cM3Yna7AavY[2]
# 0.23080353438854218
# positive
# Neutral
# 36 th data
# cM3Yna7AavY[3]
# 0.2527143061161041
# positive
# Neutral
# 37 th data
# cM3Yna7AavY[4]
# 0.2698122560977936
# positive
# Neutral
# 38 th data
# cM3Yna7AavY[5]
# 0.22701354324817657
# positive
# Neutral
# 39 th data
# cM3Yna7AavY[6]
# 0.27371931076049805
# positive
# Neutral
# 40 th data
# cM3Yna7AavY[7]
# 0.26144009828567505
# positive
# Neutral
# 41 th data
# cM3Yna7AavY[8]
# 0.2841576933860779
# positive
# Neutral
# 42 th data
# cM3Yna7AavY[9]
# 0.25866958498954773
# positive
# Neutral
# 43 th data
# cM3Yna7AavY[10]
# 0.25218215584754944
# positive
# Neutral
# 44 th data
# cM3Yna7AavY[11]
# 0.22732432186603546
# positive
# Neutral
# 45 th data
# cM3Yna7AavY[12]
# 0.2941100299358368
# positive
# Neutral
# 46 th data
# cM3Yna7AavY[13]
# 0.24710504710674286
# positive
# Neutral
# 47 th data
# cM3Yna7AavY[14]
# 0.306883305311203
# positive
# Neutral
# 48 th data
# cM3Yna7AavY[15]
# 0.27652034163475037
# positive
# Neutral
# 49 th data
# cW1FSBF59ik[0]
# 0.2882555425167084
# positive
# Neutral
# 50 th data
# cW1FSBF59ik[1]
# 0.24992121756076813
# positive
# Neutral
# 51 th data
# cW1FSBF59ik[2]
# 0.23064418137073517
# positive
# Neutral
# 52 th data
# cW1FSBF59ik[3]
# 0.17136356234550476
# positive
# Neutral
# 53 th data
# cW1FSBF59ik[4]
# 0.32241958379745483
# positive
# Neutral
# 54 th data
# cW1FSBF59ik[5]
# 0.2086821049451828
# positive
# Neutral
# 55 th data
# cW1FSBF59ik[6]
# 0.2743418514728546
# positive
# Neutral
# 56 th data
# cW1FSBF59ik[7]
# 0.29435494542121887
# positive
# Neutral
# 57 th data
# cW1FSBF59ik[8]
# 0.2813306450843811
# positive
# Neutral
# 58 th data
# cW1FSBF59ik[9]
# 0.26530909538269043
# positive
# Neutral
# 59 th data
# cW1FSBF59ik[10]
# 0.24255533516407013
# positive
# Neutral
# 60 th data
# cW1FSBF59ik[11]
# 0.20050515234470367
# positive
# Neutral
# 61 th data
# cW1FSBF59ik[12]
# 0.2640894949436188
# positive
# Neutral
# 62 th data
# cW1FSBF59ik[13]
# 0.21173153817653656
# positive
# Neutral
# 63 th data
# cW1FSBF59ik[14]
# 0.28444409370422363
# positive
# Neutral
# 64 th data
# cW1FSBF59ik[15]
# 0.23899181187152863
# positive
# Neutral
# 65 th data
# cW1FSBF59ik[16]
# 0.24625582993030548
# positive
# Neutral
# 66 th data
# cW1FSBF59ik[17]
# 0.26932600140571594
# positive
# Neutral
# 67 th data
# cW1FSBF59ik[18]
# 0.2858075201511383
# positive
# Neutral
# 68 th data
# cW1FSBF59ik[19]
# 0.1841345578432083
# positive
# Neutral
# 69 th data
# cW1FSBF59ik[20]
# 0.17457254230976105
# positive
# Neutral
# 70 th data
# cW1FSBF59ik[21]
# 0.160148486495018
# positive
# Neutral
# 71 th data
# cW1FSBF59ik[22]
# 0.34195348620414734
# positive
# Neutral
# 72 th data
# cW1FSBF59ik[23]
# 0.35183849930763245
# positive
# Neutral
# 73 th data
# cXypl4FnoZo[0]
# 0.44020769000053406
# positive
# slightly positive
# 74 th data
# cXypl4FnoZo[1]
# 0.2743600606918335
# positive
# Neutral
# 75 th data
# cXypl4FnoZo[2]
# 0.26630204916000366
# positive
# Neutral
# 76 th data
# cXypl4FnoZo[3]
# 0.20333516597747803
# positive
# Neutral
# 77 th data
# cXypl4FnoZo[4]
# 0.16470608115196228
# positive
# Neutral
# 78 th data
# cXypl4FnoZo[5]
# 0.22667120397090912
# positive
# Neutral
# 79 th data
# cXypl4FnoZo[6]
# 0.21264053881168365
# positive
# Neutral
# 80 th data
# cXypl4FnoZo[7]
# 0.22346724569797516
# positive
# Neutral
# 81 th data
# cXypl4FnoZo[8]
# 0.11606091260910034
# positive
# Neutral
# 82 th data
# cXypl4FnoZo[9]
# 0.23894725739955902
# positive
# Neutral
# 83 th data
# cXypl4FnoZo[10]
# 0.26040032505989075
# positive
# Neutral
# 84 th data
# cXypl4FnoZo[11]
# 0.338521808385849
# positive
# Neutral
# 85 th data
# cXypl4FnoZo[12]
# 0.15271809697151184
# positive
# Neutral
# 86 th data
# cXypl4FnoZo[13]
# 0.35790693759918213
# positive
# Neutral
# 87 th data
# cXypl4FnoZo[14]
# 0.24344144761562347
# positive
# Neutral
# 88 th data
# cXypl4FnoZo[15]
# 0.23927460610866547
# positive
# Neutral
# 89 th data
# cXypl4FnoZo[16]
# 0.197439044713974
# positive
# Neutral
# 90 th data
# cXypl4FnoZo[17]
# 0.11532367765903473
# positive
# Neutral
# 91 th data
# cXypl4FnoZo[18]
# 0.24518956243991852
# positive
# Neutral
# 92 th data
# cXypl4FnoZo[19]
# 0.24044008553028107
# positive
# Neutral
# 93 th data
# cXypl4FnoZo[20]
# 0.13186220824718475
# positive
# Neutral
# 94 th data
# cXypl4FnoZo[21]
# 0.2427685409784317
# positive
# Neutral
# 95 th data
# cXypl4FnoZo[22]
# 0.348087340593338
# positive
# Neutral
# 96 th data
# cXypl4FnoZo[23]
# 0.24390585720539093
# positive
# Neutral
# 97 th data
# cXypl4FnoZo[24]
# 0.3162987530231476
# positive
# Neutral
# 98 th data
# cXypl4FnoZo[25]
# 0.28418460488319397
# positive
# Neutral
# 99 th data
# cXypl4FnoZo[26]
# 0.18770235776901245
# positive
# Neutral
# 100 th data
# cXypl4FnoZo[27]
# 0.2763066291809082
# positive
# Neutral
# 101 th data
# cXypl4FnoZo[28]
# 0.23768772184848785
# positive
# Neutral
# 102 th data
# d3_k5Xpfmik[0]
# 0.29726287722587585
# positive
# Neutral
# 103 th data
# d3_k5Xpfmik[1]
# 0.27766507863998413
# positive
# Neutral
# 104 th data
# d3_k5Xpfmik[2]
# 0.22557570040225983
# positive
# Neutral
# 105 th data
# d3_k5Xpfmik[3]
# 0.2282363325357437
# positive
# Neutral
# 106 th data
# d3_k5Xpfmik[4]
# 0.26426059007644653
# positive
# Neutral
# 107 th data
# d3_k5Xpfmik[5]
# 0.27955594658851624
# positive
# Neutral
# 108 th data
# d3_k5Xpfmik[6]
# 0.21561704576015472
# positive
# Neutral
# 109 th data
# d3_k5Xpfmik[7]
# 0.22757138311862946
# positive
# Neutral
# 110 th data
# d3_k5Xpfmik[8]
# 0.1521066278219223
# positive
# Neutral
# 111 th data
# d3_k5Xpfmik[9]
# 0.3030988276004791
# positive
# Neutral
# 112 th data
# d3_k5Xpfmik[10]
# 0.24454493820667267
# positive
# Neutral
# 113 th data
# d3_k5Xpfmik[11]
# 0.20100373029708862
# positive
# Neutral
# 114 th data
# d3_k5Xpfmik[12]
# 0.1486692726612091
# positive
# Neutral
# 115 th data
# d3_k5Xpfmik[13]
# 0.17459605634212494
# positive
# Neutral
# 116 th data
# d3_k5Xpfmik[14]
# 0.2774350345134735
# positive
# Neutral
# 117 th data
# d3_k5Xpfmik[15]
# 0.17946283519268036
# positive
# Neutral
# 118 th data
# d3_k5Xpfmik[16]
# 0.2219512015581131
# positive
# Neutral
# 119 th data
# d3_k5Xpfmik[17]
# 0.3307605981826782
# positive
# Neutral
# 120 th data
# d3_k5Xpfmik[18]
# 0.3234030306339264
# positive
# Neutral
# 121 th data
# d6hH302o4v8[0]
# 0.19376759231090546
# positive
# Neutral
# 122 th data
# d6hH302o4v8[1]
# 0.22249232232570648
# positive
# Neutral
# 123 th data
# d6hH302o4v8[2]
# 0.3039321005344391
# positive
# Neutral
# 124 th data
# d6hH302o4v8[3]
# 0.3311554491519928
# positive
# Neutral
# 125 th data
# d6hH302o4v8[4]
# 0.22874502837657928
# positive
# Neutral
# 126 th data
# d6hH302o4v8[5]
# 0.3108149468898773
# positive
# Neutral
# 127 th data
# d6hH302o4v8[6]
# 0.3275603950023651
# positive
# Neutral
# 128 th data
# d6hH302o4v8[7]
# 0.2624782621860504
# positive
# Neutral
# 129 th data
# d6hH302o4v8[8]
# 0.17951710522174835
# positive
# Neutral
# 130 th data
# d6hH302o4v8[9]
# 0.316371887922287
# positive
# Neutral
# 131 th data
# d6hH302o4v8[10]
# 0.1690828949213028
# positive
# Neutral
# 132 th data
# d6hH302o4v8[11]
# 0.2729226350784302
# positive
# Neutral
# 133 th data
# d6hH302o4v8[12]
# 0.172570139169693
# positive
# Neutral
# 134 th data
# d6hH302o4v8[13]
# 0.2182014137506485
# positive
# Neutral
# 135 th data
# d6hH302o4v8[14]
# 0.27315187454223633
# positive
# Neutral
# 136 th data
# d6hH302o4v8[15]
# 0.2969036400318146
# positive
# Neutral
# 137 th data
# d6hH302o4v8[16]
# 0.2691127061843872
# positive
# Neutral
# 138 th data
# d6hH302o4v8[17]
# 0.20715323090553284
# positive
# Neutral
# 139 th data
# d6hH302o4v8[18]
# 0.21612291038036346
# positive
# Neutral
# 140 th data
# d6hH302o4v8[19]
# 0.22297169268131256
# positive
# Neutral
# 141 th data
# d6hH302o4v8[20]
# 0.132343128323555
# positive
# Neutral
# 142 th data
# d6hH302o4v8[21]
# 0.24242834746837616
# positive
# Neutral
# 143 th data
# d6hH302o4v8[22]
# 0.20637619495391846
# positive
# Neutral
# 144 th data
# d6hH302o4v8[23]
# 0.24432195723056793
# positive
# Neutral
# 145 th data
# d6hH302o4v8[24]
# 0.28138700127601624
# positive
# Neutral
# 146 th data
# d6hH302o4v8[25]
# 0.28310415148735046
# positive
# Neutral
# 147 th data
# d6hH302o4v8[26]
# 0.24804790318012238
# positive
# Neutral
# 148 th data
# d6hH302o4v8[27]
# 0.17227116227149963
# positive
# Neutral
# 149 th data
# d6hH302o4v8[28]
# 0.29589298367500305
# positive
# Neutral
# 150 th data
# d6hH302o4v8[29]
# 0.308795303106308
# positive
# Neutral
# 151 th data
# d6hH302o4v8[30]
# 0.11635367572307587
# positive
# Neutral
# 152 th data
# d6hH302o4v8[31]
# 0.2724476456642151
# positive
# Neutral
# 153 th data
# d6hH302o4v8[32]
# 0.2722572684288025
# positive
# Neutral
# 154 th data
# d6hH302o4v8[33]
# 0.24802850186824799
# positive
# Neutral
# 155 th data
# d6hH302o4v8[34]
# 0.30933746695518494
# positive
# Neutral
# 156 th data
# d6hH302o4v8[35]
# 0.21563838422298431
# positive
# Neutral
# 157 th data
# d6hH302o4v8[36]
# 0.2243575006723404
# positive
# Neutral
# 158 th data
# d6hH302o4v8[37]
# 0.3093291223049164
# positive
# Neutral
# 159 th data
# d6hH302o4v8[38]
# 0.2725227177143097
# positive
# Neutral
# 160 th data
# d6hH302o4v8[39]
# 0.3121253550052643
# positive
# Neutral
# 161 th data
# d6hH302o4v8[40]
# 0.2315768152475357
# positive
# Neutral
# 162 th data
# d6hH302o4v8[41]
# 0.24907876551151276
# positive
# Neutral
# 163 th data
# d6hH302o4v8[42]
# 0.3052017390727997
# positive
# Neutral
# 164 th data
# dq3Nf_lMPnE[0]
# 0.2561604082584381
# positive
# Neutral
# 165 th data
# dq3Nf_lMPnE[1]
# 0.1884494572877884
# positive
# Neutral
# 166 th data
# dq3Nf_lMPnE[2]
# 0.24649830162525177
# positive
# Neutral
# 167 th data
# dq3Nf_lMPnE[3]
# 0.21317829191684723
# positive
# Neutral
# 168 th data
# dq3Nf_lMPnE[4]
# 0.26390066742897034
# positive
# Neutral
# 169 th data
# dq3Nf_lMPnE[5]
# 0.3775654733181
# positive
# Neutral
# 170 th data
# dq3Nf_lMPnE[6]
# 0.25989672541618347
# positive
# Neutral
# 171 th data
# dq3Nf_lMPnE[7]
# 0.2498675137758255
# positive
# Neutral
# 172 th data
# dq3Nf_lMPnE[8]
# 0.167410746216774
# positive
# Neutral
# 173 th data
# dq3Nf_lMPnE[9]
# 0.3054888844490051
# positive
# Neutral
# 174 th data
# dq3Nf_lMPnE[10]
# 0.39835378527641296
# positive
# Neutral
# 175 th data
# dq3Nf_lMPnE[11]
# 0.2960946261882782
# positive
# Neutral
# 176 th data
# dq3Nf_lMPnE[12]
# 0.32939612865448
# positive
# Neutral
# 177 th data
# dq3Nf_lMPnE[13]
# 0.2788328528404236
# positive
# Neutral
# 178 th data
# dq3Nf_lMPnE[14]
# 0.3039970397949219
# positive
# Neutral
# 179 th data
# etzxEpPuc6I[0]
# 0.24085326492786407
# positive
# Neutral
# 180 th data
# etzxEpPuc6I[1]
# 0.15182103216648102
# positive
# Neutral
# 181 th data
# etzxEpPuc6I[2]
# 0.20056849718093872
# positive
# Neutral
# 182 th data
# etzxEpPuc6I[3]
# 0.20918388664722443
# positive
# Neutral
# 183 th data
# etzxEpPuc6I[4]
# 0.24128760397434235
# positive
# Neutral
# 184 th data
# etzxEpPuc6I[5]
# 0.3539348542690277
# positive
# Neutral
# 185 th data
# etzxEpPuc6I[6]
# 0.2386043816804886
# positive
# Neutral
# 186 th data
# etzxEpPuc6I[7]
# 0.23606370389461517
# positive
# Neutral
# 187 th data
# etzxEpPuc6I[8]
# 0.1283237189054489
# positive
# Neutral
# 188 th data
# etzxEpPuc6I[9]
# 0.21806199848651886
# positive
# Neutral
# 189 th data
# etzxEpPuc6I[10]
# 0.14649704098701477
# positive
# Neutral
# 190 th data
# etzxEpPuc6I[11]
# 0.20335383713245392
# positive
# Neutral
# 191 th data
# etzxEpPuc6I[12]
# 0.26627984642982483
# positive
# Neutral
# 192 th data
# etzxEpPuc6I[13]
# 0.19813160598278046
# positive
# Neutral
# 193 th data
# etzxEpPuc6I[14]
# 0.2255704551935196
# positive
# Neutral
# 194 th data
# etzxEpPuc6I[15]
# 0.29881396889686584
# positive
# Neutral
# 195 th data
# etzxEpPuc6I[16]
# 0.23811228573322296
# positive
# Neutral
# 196 th data
# etzxEpPuc6I[17]
# 0.20124909281730652
# positive
# Neutral
# 197 th data
# etzxEpPuc6I[18]
# 0.22146041691303253
# positive
# Neutral
# 198 th data
# f9O3YtZ2VfI[0]
# 0.2014290690422058
# positive
# Neutral
# 199 th data
# f9O3YtZ2VfI[1]
# 0.31714943051338196
# positive
# Neutral
# 200 th data
# f9O3YtZ2VfI[2]
# 0.37654390931129456
# positive
# Neutral
# 201 th data
# f9O3YtZ2VfI[3]
# 0.2742469608783722
# positive
# Neutral
# 202 th data
# f9O3YtZ2VfI[4]
# 0.25511834025382996
# positive
# Neutral
# 203 th data
# f9O3YtZ2VfI[5]
# 0.31543025374412537
# positive
# Neutral
# 204 th data
# f9O3YtZ2VfI[6]
# 0.225027933716774
# positive
# Neutral
# 205 th data
# f9O3YtZ2VfI[7]
# 0.353889137506485
# positive
# Neutral
# 206 th data
# f9O3YtZ2VfI[8]
# 0.18135786056518555
# positive
# Neutral
# 207 th data
# f9O3YtZ2VfI[9]
# 0.29094913601875305
# positive
# Neutral
# 208 th data
# f9O3YtZ2VfI[10]
# 0.2045416384935379
# positive
# Neutral
# 209 th data
# f9O3YtZ2VfI[11]
# 0.12226557731628418
# positive
# Neutral
# 210 th data
# f9O3YtZ2VfI[12]
# 0.3946826756000519
# positive
# Neutral
# 211 th data
# f9O3YtZ2VfI[13]
# 0.28118714690208435
# positive
# Neutral
# 212 th data
# f9O3YtZ2VfI[14]
# 0.2625100016593933
# positive
# Neutral
# 213 th data
# f9O3YtZ2VfI[15]
# 0.20720413327217102
# positive
# Neutral
# 214 th data
# f9O3YtZ2VfI[16]
# 0.20036812126636505
# positive
# Neutral
# 215 th data
# f9O3YtZ2VfI[17]
# 0.20803742110729218
# positive
# Neutral
# 216 th data
# f9O3YtZ2VfI[18]
# 0.16714923083782196
# positive
# Neutral
# 217 th data
# f9O3YtZ2VfI[19]
# 0.23789377510547638
# positive
# Neutral
# 218 th data
# f9O3YtZ2VfI[20]
# 0.3195961117744446
# positive
# Neutral
# 219 th data
# f9O3YtZ2VfI[21]
# 0.2643115818500519
# positive
# Neutral
# 220 th data
# f9O3YtZ2VfI[22]
# 0.15812058746814728
# positive
# Neutral
# 221 th data
# f9O3YtZ2VfI[23]
# 0.2603747546672821
# positive
# Neutral
# 222 th data
# f9O3YtZ2VfI[24]
# 0.16909272968769073
# positive
# Neutral
# 223 th data
# f9O3YtZ2VfI[25]
# 0.3393367826938629
# positive
# Neutral
# 224 th data
# f9O3YtZ2VfI[26]
# 0.3205901086330414
# positive
# Neutral
# 225 th data
# f9O3YtZ2VfI[27]
# 0.2560561001300812
# positive
# Neutral
# 226 th data
# f9O3YtZ2VfI[28]
# 0.18229535222053528
# positive
# Neutral
# 227 th data
# f9O3YtZ2VfI[29]
# 0.3819528818130493
# positive
# Neutral
# 228 th data
# f_pcplsH_V0[0]
# 0.2522898018360138
# positive
# Neutral
# 229 th data
# f_pcplsH_V0[1]
# 0.289430171251297
# positive
# Neutral
# 230 th data
# f_pcplsH_V0[2]
# 0.20164614915847778
# positive
# Neutral
# 231 th data
# f_pcplsH_V0[3]
# 0.3185596764087677
# positive
# Neutral
# 232 th data
# f_pcplsH_V0[4]
# 0.2615908682346344
# positive
# Neutral
# 233 th data
# f_pcplsH_V0[5]
# 0.20043572783470154
# positive
# Neutral
# 234 th data
# f_pcplsH_V0[6]
# 0.2102057784795761
# positive
# Neutral
# 235 th data
# f_pcplsH_V0[7]
# 0.2843535542488098
# positive
# Neutral
# 236 th data
# f_pcplsH_V0[8]
# 0.23036329448223114
# positive
# Neutral
# 237 th data
# f_pcplsH_V0[9]
# 0.26899293065071106
# positive
# Neutral
# 238 th data
# f_pcplsH_V0[10]
# 0.14087070524692535
# positive
# Neutral
# 239 th data
# f_pcplsH_V0[11]
# 0.2782496511936188
# positive
# Neutral
# 240 th data
# f_pcplsH_V0[12]
# 0.26161494851112366
# positive
# Neutral
# 241 th data
# f_pcplsH_V0[13]
# 0.355355829000473
# positive
# Neutral
# 242 th data
# f_pcplsH_V0[14]
# 0.21346785128116608
# positive
# Neutral
# 243 th data
# fvVhgmXxadc[0]
# 0.24633993208408356
# positive
# Neutral
# 244 th data
# fvVhgmXxadc[1]
# 0.2647201120853424
# positive
# Neutral
# 245 th data
# fvVhgmXxadc[2]
# 0.19784142076969147
# positive
# Neutral
# 246 th data
# fvVhgmXxadc[3]
# 0.21599091589450836
# positive
# Neutral
# 247 th data
# fvVhgmXxadc[4]
# 0.18819041550159454
# positive
# Neutral
# 248 th data
# fvVhgmXxadc[5]
# 0.13169731199741364
# positive
# Neutral
# 249 th data
# fvVhgmXxadc[6]
# 0.160525843501091
# positive
# Neutral
# 250 th data
# fvVhgmXxadc[7]
# 0.20317895710468292
# positive
# Neutral
# 251 th data
# fvVhgmXxadc[8]
# 0.26147475838661194
# positive
# Neutral
# 252 th data
# fvVhgmXxadc[9]
# 0.12678977847099304
# positive
# Neutral
# 253 th data
# fvVhgmXxadc[10]
# 0.24146540462970734
# positive
# Neutral
# 254 th data
# fvVhgmXxadc[11]
# 0.09768128395080566
# positive
# Neutral
# 255 th data
# fvVhgmXxadc[12]
# 0.20408430695533752
# positive
# Neutral
# 256 th data
# fvVhgmXxadc[13]
# 0.26303353905677795
# positive
# Neutral
# 257 th data
# iiK8YX8oH1E[0]
# 0.2964022755622864
# positive
# Neutral
# 258 th data
# iiK8YX8oH1E[1]
# 0.34009987115859985
# positive
# Neutral
# 259 th data
# iiK8YX8oH1E[2]
# 0.2971341907978058
# positive
# Neutral
# 260 th data
# iiK8YX8oH1E[3]
# 0.21480987966060638
# positive
# Neutral
# 261 th data
# iiK8YX8oH1E[4]
# 0.2507632076740265
# positive
# Neutral
# 262 th data
# iiK8YX8oH1E[5]
# 0.18227188289165497
# positive
# Neutral
# 263 th data
# iiK8YX8oH1E[6]
# 0.29506412148475647
# positive
# Neutral
# 264 th data
# iiK8YX8oH1E[7]
# 0.27300089597702026
# positive
# Neutral
# 265 th data
# iiK8YX8oH1E[8]
# 0.18114055693149567
# positive
# Neutral
# 266 th data
# iiK8YX8oH1E[9]
# 0.23268045485019684
# positive
# Neutral
# 267 th data
# iiK8YX8oH1E[10]
# 0.21415849030017853
# positive
# Neutral
# 268 th data
# iiK8YX8oH1E[11]
# 0.3168642818927765
# positive
# Neutral
# 269 th data
# iiK8YX8oH1E[12]
# 0.2916107773780823
# positive
# Neutral
# 270 th data
# iiK8YX8oH1E[13]
# 0.22560425102710724
# positive
# Neutral
# 271 th data
# iiK8YX8oH1E[14]
# 0.2914314568042755
# positive
# Neutral
# 272 th data
# iiK8YX8oH1E[15]
# 0.3027017414569855
# positive
# Neutral
# 273 th data
# iiK8YX8oH1E[16]
# 0.2458401471376419
# positive
# Neutral
# 274 th data
# iiK8YX8oH1E[17]
# 0.28045329451560974
# positive
# Neutral
# 275 th data
# jUzDDGyPkXU[0]
# 0.38389769196510315
# positive
# Neutral
# 276 th data
# jUzDDGyPkXU[1]
# 0.24962584674358368
# positive
# Neutral
# 277 th data
# jUzDDGyPkXU[2]
# 0.24895085394382477
# positive
# Neutral
# 278 th data
# jUzDDGyPkXU[3]
# 0.35380038619041443
# positive
# Neutral
# 279 th data
# jUzDDGyPkXU[4]
# 0.281901091337204
# positive
# Neutral
# 280 th data
# jUzDDGyPkXU[5]
# 0.20347969233989716
# positive
# Neutral
# 281 th data
# jUzDDGyPkXU[6]
# 0.16957424581050873
# positive
# Neutral
# 282 th data
# jUzDDGyPkXU[7]
# 0.17705866694450378
# positive
# Neutral
# 283 th data
# jUzDDGyPkXU[8]
# 0.2605261206626892
# positive
# Neutral
# 284 th data
# jUzDDGyPkXU[9]
# 0.3034740090370178
# positive
# Neutral
# 285 th data
# jUzDDGyPkXU[10]
# 0.23506112396717072
# positive
# Neutral
# 286 th data
# jUzDDGyPkXU[11]
# 0.296548068523407
# positive
# Neutral
# 287 th data
# jUzDDGyPkXU[12]
# 0.3317669928073883
# positive
# Neutral
# 288 th data
# jUzDDGyPkXU[13]
# 0.44126108288764954
# positive
# slightly positive
# 289 th data
# jUzDDGyPkXU[14]
# 0.20834951102733612
# positive
# Neutral
# 290 th data
# jUzDDGyPkXU[15]
# 0.29113680124282837
# positive
# Neutral
# 291 th data
# jUzDDGyPkXU[16]
# 0.2630651295185089
# positive
# Neutral
# 292 th data
# jUzDDGyPkXU[17]
# 0.3068517744541168
# positive
# Neutral
# 293 th data
# jUzDDGyPkXU[18]
# 0.25997182726860046
# positive
# Neutral
# 294 th data
# jUzDDGyPkXU[19]
# 0.2540946900844574
# positive
# Neutral
# 295 th data
# jUzDDGyPkXU[20]
# 0.23542161285877228
# positive
# Neutral
# 296 th data
# jUzDDGyPkXU[21]
# 0.18492822349071503
# positive
# Neutral
# 297 th data
# jUzDDGyPkXU[22]
# 0.2411680966615677
# positive
# Neutral
# 298 th data
# jUzDDGyPkXU[23]
# 0.18253810703754425
# positive
# Neutral
# 299 th data
# jUzDDGyPkXU[24]
# 0.1704234629869461
# positive
# Neutral
# 300 th data
# jUzDDGyPkXU[25]
# 0.20556049048900604
# positive
# Neutral
# 301 th data
# jUzDDGyPkXU[26]
# 0.2573036253452301
# positive
# Neutral
# 302 th data
# k5Y_838nuGo[0]
# 0.2600369155406952
# positive
# Neutral
# 303 th data
# k5Y_838nuGo[1]
# 0.316931813955307
# positive
# Neutral
# 304 th data
# k5Y_838nuGo[2]
# 0.3516825735569
# positive
# Neutral
# 305 th data
# k5Y_838nuGo[3]
# 0.24336467683315277
# positive
# Neutral
# 306 th data
# k5Y_838nuGo[4]
# 0.25813618302345276
# positive
# Neutral
# 307 th data
# k5Y_838nuGo[5]
# 0.21358616650104523
# positive
# Neutral
# 308 th data
# k5Y_838nuGo[6]
# 0.21168895065784454
# positive
# Neutral
# 309 th data
# k5Y_838nuGo[7]
# 0.23041851818561554
# positive
# Neutral
# 310 th data
# k5Y_838nuGo[8]
# 0.2656596601009369
# positive
# Neutral
# 311 th data
# k5Y_838nuGo[9]
# 0.1767367124557495
# positive
# Neutral
# 312 th data
# k5Y_838nuGo[10]
# 0.2221612185239792
# positive
# Neutral
# 313 th data
# k5Y_838nuGo[11]
# 0.2744952142238617
# positive
# Neutral
# 314 th data
# k5Y_838nuGo[12]
# 0.2769934833049774
# positive
# Neutral
# 315 th data
# k5Y_838nuGo[13]
# 0.2415568083524704
# positive
# Neutral
# 316 th data
# k5Y_838nuGo[14]
# 0.2811483144760132
# positive
# Neutral
# 317 th data
# k5Y_838nuGo[15]
# 0.21068356931209564
# positive
# Neutral
# 318 th data
# k5Y_838nuGo[16]
# 0.17271405458450317
# positive
# Neutral
# 319 th data
# k5Y_838nuGo[17]
# 0.3157389461994171
# positive
# Neutral
# 320 th data
# k5Y_838nuGo[18]
# 0.26648929715156555
# positive
# Neutral
# 321 th data
# k5Y_838nuGo[19]
# 0.19357727468013763
# positive
# Neutral
# 322 th data
# k5Y_838nuGo[20]
# 0.27442848682403564
# positive
# Neutral
# 323 th data
# k5Y_838nuGo[21]
# 0.27816638350486755
# positive
# Neutral
# 324 th data
# k5Y_838nuGo[22]
# 0.27755263447761536
# positive
# Neutral
# 325 th data
# k5Y_838nuGo[23]
# 0.270559698343277
# positive
# Neutral
# 326 th data
# k5Y_838nuGo[24]
# 0.17684300243854523
# positive
# Neutral
# 327 th data
# k5Y_838nuGo[25]
# 0.2481706291437149
# positive
# Neutral
# 328 th data
# k5Y_838nuGo[26]
# 0.2699315845966339
# positive
# Neutral
# 329 th data
# k5Y_838nuGo[27]
# 0.334046334028244
# positive
# Neutral
# 330 th data
# k5Y_838nuGo[28]
# 0.30207446217536926
# positive
# Neutral
# 331 th data
# k5Y_838nuGo[29]
# 0.19518716633319855
# positive
# Neutral
# 332 th data
# k5Y_838nuGo[30]
# 0.2627764344215393
# positive
# Neutral
# 333 th data
# lXPQBPVc5Cw[0]
# 0.27563056349754333
# positive
# Neutral
# 334 th data
# lXPQBPVc5Cw[1]
# 0.3159787356853485
# positive
# Neutral
# 335 th data
# lXPQBPVc5Cw[2]
# 0.240581676363945
# positive
# Neutral
# 336 th data
# lXPQBPVc5Cw[3]
# 0.2863825261592865
# positive
# Neutral
# 337 th data
# lXPQBPVc5Cw[4]
# 0.20218759775161743
# positive
# Neutral
# 338 th data
# lXPQBPVc5Cw[5]
# 0.21381725370883942
# positive
# Neutral
# 339 th data
# lXPQBPVc5Cw[6]
# 0.1815885752439499
# positive
# Neutral
# 340 th data
# lXPQBPVc5Cw[7]
# 0.3443726599216461
# positive
# Neutral
# 341 th data
# lXPQBPVc5Cw[8]
# 0.07454884052276611
# positive
# Neutral
# 342 th data
# lXPQBPVc5Cw[9]
# 0.2865864336490631
# positive
# Neutral
# 343 th data
# lXPQBPVc5Cw[10]
# 0.27132388949394226
# positive
# Neutral
# 344 th data
# lXPQBPVc5Cw[11]
# 0.10676644742488861
# positive
# Neutral
# 345 th data
# lXPQBPVc5Cw[12]
# 0.38665279746055603
# positive
# Neutral
# 346 th data
# lXPQBPVc5Cw[13]
# 0.11470045149326324
# positive
# Neutral
# 347 th data
# lXPQBPVc5Cw[14]
# 0.2518250346183777
# positive
# Neutral
# 348 th data
# lXPQBPVc5Cw[15]
# 0.22820039093494415
# positive
# Neutral
# 349 th data
# lXPQBPVc5Cw[16]
# 0.23534150421619415
# positive
# Neutral
# 350 th data
# lXPQBPVc5Cw[17]
# 0.2990066707134247
# positive
# Neutral
# 351 th data
# lXPQBPVc5Cw[18]
# 0.18744529783725739
# positive
# Neutral
# 352 th data
# lXPQBPVc5Cw[19]
# 0.23394669592380524
# positive
# Neutral
# 353 th data
# lXPQBPVc5Cw[20]
# 0.16850559413433075
# positive
# Neutral
# 354 th data
# lXPQBPVc5Cw[21]
# 0.2829515039920807
# positive
# Neutral
# 355 th data
# lXPQBPVc5Cw[22]
# 0.25592729449272156
# positive
# Neutral
# 356 th data
# lXPQBPVc5Cw[23]
# 0.306209921836853
# positive
# Neutral
# 357 th data
# lXPQBPVc5Cw[24]
# 0.2109813541173935
# positive
# Neutral
# 358 th data
# lXPQBPVc5Cw[25]
# 0.23627062141895294
# positive
# Neutral
# 359 th data
# lXPQBPVc5Cw[26]
# 0.1551295667886734
# positive
# Neutral
# 360 th data
# lXPQBPVc5Cw[27]
# 0.18360963463783264
# positive
# Neutral
# 361 th data
# lXPQBPVc5Cw[28]
# 0.33846744894981384
# positive
# Neutral
# 362 th data
# nbWiPyCm4g0[0]
# 0.09721797704696655
# positive
# Neutral
# 363 th data
# nbWiPyCm4g0[1]
# 0.23608191311359406
# positive
# Neutral
# 364 th data
# nbWiPyCm4g0[2]
# 0.2838158905506134
# positive
# Neutral
# 365 th data
# nbWiPyCm4g0[3]
# 0.1985272616147995
# positive
# Neutral
# 366 th data
# nbWiPyCm4g0[4]
# 0.22871457040309906
# positive
# Neutral
# 367 th data
# nbWiPyCm4g0[5]
# 0.2064514458179474
# positive
# Neutral
# 368 th data
# nbWiPyCm4g0[6]
# 0.22114945948123932
# positive
# Neutral
# 369 th data
# nbWiPyCm4g0[7]
# 0.2334284633398056
# positive
# Neutral
# 370 th data
# nbWiPyCm4g0[8]
# 0.17126016318798065
# positive
# Neutral
# 371 th data
# nbWiPyCm4g0[9]
# 0.29956814646720886
# positive
# Neutral
# 372 th data
# nzpVDcQ0ywM[0]
# 0.1669396460056305
# positive
# Neutral
# 373 th data
# nzpVDcQ0ywM[1]
# 0.23410604894161224
# positive
# Neutral
# 374 th data
# nzpVDcQ0ywM[2]
# 0.21270893514156342
# positive
# Neutral
# 375 th data
# nzpVDcQ0ywM[3]
# 0.2825717628002167
# positive
# Neutral
# 376 th data
# nzpVDcQ0ywM[4]
# 0.2874300181865692
# positive
# Neutral
# 377 th data
# nzpVDcQ0ywM[5]
# 0.1774265170097351
# positive
# Neutral
# 378 th data
# nzpVDcQ0ywM[6]
# 0.3334493339061737
# positive
# Neutral
# 379 th data
# nzpVDcQ0ywM[7]
# 0.31715816259384155
# positive
# Neutral
# 380 th data
# nzpVDcQ0ywM[8]
# 0.2756355106830597
# positive
# Neutral
# 381 th data
# nzpVDcQ0ywM[9]
# 0.16653430461883545
# positive
# Neutral
# 382 th data
# nzpVDcQ0ywM[10]
# 0.1905960887670517
# positive
# Neutral
# 383 th data
# nzpVDcQ0ywM[11]
# 0.22832103073596954
# positive
# Neutral
# 384 th data
# nzpVDcQ0ywM[12]
# 0.4077076315879822
# positive
# Neutral
# 385 th data
# nzpVDcQ0ywM[13]
# 0.3196198046207428
# positive
# Neutral
# 386 th data
# nzpVDcQ0ywM[14]
# 0.3074900209903717
# positive
# Neutral
# 387 th data
# nzpVDcQ0ywM[15]
# 0.22921539843082428
# positive
# Neutral
# 388 th data
# nzpVDcQ0ywM[16]
# 0.33061638474464417
# positive
# Neutral
# 389 th data
# nzpVDcQ0ywM[17]
# 0.21369747817516327
# positive
# Neutral
# 390 th data
# nzpVDcQ0ywM[18]
# 0.3131055235862732
# positive
# Neutral
# 391 th data
# nzpVDcQ0ywM[19]
# 0.38397273421287537
# positive
# Neutral
# 392 th data
# nzpVDcQ0ywM[20]
# 0.23875321447849274
# positive
# Neutral
# 393 th data
# nzpVDcQ0ywM[21]
# 0.3351299464702606
# positive
# Neutral
# 394 th data
# nzpVDcQ0ywM[22]
# 0.2803970277309418
# positive
# Neutral
# 395 th data
# nzpVDcQ0ywM[23]
# 0.1634082943201065
# positive
# Neutral
# 396 th data
# ob23OKe5a9Q[0]
# 0.23204012215137482
# positive
# Neutral
# 397 th data
# ob23OKe5a9Q[1]
# 0.2870272994041443
# positive
# Neutral
# 398 th data
# ob23OKe5a9Q[2]
# 0.2839953601360321
# positive
# Neutral
# 399 th data
# ob23OKe5a9Q[3]
# 0.28720584511756897
# positive
# Neutral
# 400 th data
# ob23OKe5a9Q[4]
# 0.20042967796325684
# positive
# Neutral
# 401 th data
# ob23OKe5a9Q[5]
# 0.39634963870048523
# positive
# Neutral
# 402 th data
# ob23OKe5a9Q[6]
# 0.2693370282649994
# positive
# Neutral
# 403 th data
# ob23OKe5a9Q[7]
# 0.18616662919521332
# positive
# Neutral
# 404 th data
# ob23OKe5a9Q[8]
# 0.24429692327976227
# positive
# Neutral
# 405 th data
# ob23OKe5a9Q[9]
# 0.23937828838825226
# positive
# Neutral
# 406 th data
# ob23OKe5a9Q[10]
# 0.29594406485557556
# positive
# Neutral
# 407 th data
# ob23OKe5a9Q[11]
# 0.2527872622013092
# positive
# Neutral
# 408 th data
# ob23OKe5a9Q[12]
# 0.1840680092573166
# positive
# Neutral
# 409 th data
# ob23OKe5a9Q[13]
# 0.235412135720253
# positive
# Neutral
# 410 th data
# pLTX3ipuDJI[0]
# 0.3113444149494171
# positive
# Neutral
# 411 th data
# pLTX3ipuDJI[1]
# 0.3155846893787384
# positive
# Neutral
# 412 th data
# pLTX3ipuDJI[2]
# 0.17978768050670624
# positive
# Neutral
# 413 th data
# pLTX3ipuDJI[3]
# 0.2573968470096588
# positive
# Neutral
# 414 th data
# pLTX3ipuDJI[4]
# 0.2545592486858368
# positive
# Neutral
# 415 th data
# pLTX3ipuDJI[5]
# 0.32194170355796814
# positive
# Neutral
# 416 th data
# pLTX3ipuDJI[6]
# 0.2558082938194275
# positive
# Neutral
# 417 th data
# pLTX3ipuDJI[7]
# 0.17046456038951874
# positive
# Neutral
# 418 th data
# pLTX3ipuDJI[8]
# 0.20695556700229645
# positive
# Neutral
# 419 th data
# pLTX3ipuDJI[9]
# 0.11168836057186127
# positive
# Neutral
# 420 th data
# pLTX3ipuDJI[10]
# 0.09472005069255829
# positive
# Neutral
# 421 th data
# pLTX3ipuDJI[11]
# 0.3492327630519867
# positive
# Neutral
# 422 th data
# pLTX3ipuDJI[12]
# 0.28366217017173767
# positive
# Neutral
# 423 th data
# pLTX3ipuDJI[13]
# 0.295249879360199
# positive
# Neutral
# 424 th data
# pLTX3ipuDJI[14]
# 0.3570198118686676
# positive
# Neutral
# 425 th data
# pLTX3ipuDJI[15]
# 0.1687522679567337
# positive
# Neutral
# 426 th data
# phBUpBr1hSo[0]
# 0.24354644119739532
# positive
# Neutral
# 427 th data
# phBUpBr1hSo[1]
# 0.26217183470726013
# positive
# Neutral
# 428 th data
# phBUpBr1hSo[2]
# 0.2181343287229538
# positive
# Neutral
# 429 th data
# phBUpBr1hSo[3]
# 0.18831779062747955
# positive
# Neutral
# 430 th data
# phBUpBr1hSo[4]
# 0.22370310127735138
# positive
# Neutral
# 431 th data
# phBUpBr1hSo[5]
# 0.3007456958293915
# positive
# Neutral
# 432 th data
# phBUpBr1hSo[6]
# 0.1987317055463791
# positive
# Neutral
# 433 th data
# phBUpBr1hSo[7]
# 0.25862976908683777
# positive
# Neutral
# 434 th data
# phBUpBr1hSo[8]
# 0.2375514656305313
# positive
# Neutral
# 435 th data
# phBUpBr1hSo[9]
# 0.26152920722961426
# positive
# Neutral
# 436 th data
# phBUpBr1hSo[10]
# 0.22438766062259674
# positive
# Neutral
# 437 th data
# phBUpBr1hSo[11]
# 0.13732247054576874
# positive
# Neutral
# 438 th data
# phBUpBr1hSo[12]
# 0.15095795691013336
# positive
# Neutral
# 439 th data
# phBUpBr1hSo[13]
# 0.23295451700687408
# positive
# Neutral
# 440 th data
# phBUpBr1hSo[14]
# 0.1964385062456131
# positive
# Neutral
# 441 th data
# phBUpBr1hSo[15]
# 0.2869146764278412
# positive
# Neutral
# 442 th data
# phBUpBr1hSo[16]
# 0.2674238681793213
# positive
# Neutral
# 443 th data
# phBUpBr1hSo[17]
# 0.23715443909168243
# positive
# Neutral
# 444 th data
# phBUpBr1hSo[18]
# 0.32737675309181213
# positive
# Neutral
# 445 th data
# phBUpBr1hSo[19]
# 0.2048465758562088
# positive
# Neutral
# 446 th data
# phBUpBr1hSo[20]
# 0.3493906259536743
# positive
# Neutral
# 447 th data
# rnaNMUZpvvg[0]
# 0.15945418179035187
# positive
# Neutral
# 448 th data
# rnaNMUZpvvg[1]
# 0.28645309805870056
# positive
# Neutral
# 449 th data
# rnaNMUZpvvg[2]
# 0.19218814373016357
# positive
# Neutral
# 450 th data
# rnaNMUZpvvg[3]
# 0.20771853625774384
# positive
# Neutral
# 451 th data
# rnaNMUZpvvg[4]
# 0.3026544451713562
# positive
# Neutral
# 452 th data
# rnaNMUZpvvg[5]
# 0.17265787720680237
# positive
# Neutral
# 453 th data
# rnaNMUZpvvg[6]
# 0.2704993188381195
# positive
# Neutral
# 454 th data
# rnaNMUZpvvg[7]
# 0.2405095249414444
# positive
# Neutral
# 455 th data
# rnaNMUZpvvg[8]
# 0.2310629040002823
# positive
# Neutral
# 456 th data
# rnaNMUZpvvg[9]
# 0.26192107796669006
# positive
# Neutral
# 457 th data
# rnaNMUZpvvg[10]
# 0.17529314756393433
# positive
# Neutral
# 458 th data
# rnaNMUZpvvg[11]
# 0.27600333094596863
# positive
# Neutral
# 459 th data
# rnaNMUZpvvg[12]
# 0.21397708356380463
# positive
# Neutral
# 460 th data
# rnaNMUZpvvg[13]
# 0.283547580242157
# positive
# Neutral
# 461 th data
# rnaNMUZpvvg[14]
# 0.21540068089962006
# positive
# Neutral
# 462 th data
# rnaNMUZpvvg[15]
# 0.21496088802814484
# positive
# Neutral
# 463 th data
# rnaNMUZpvvg[16]
# 0.25338801741600037
# positive
# Neutral
# 464 th data
# rnaNMUZpvvg[17]
# 0.26375290751457214
# positive
# Neutral
# 465 th data
# rnaNMUZpvvg[18]
# 0.17022553086280823
# positive
# Neutral
# 466 th data
# rnaNMUZpvvg[19]
# 0.2325925976037979
# positive
# Neutral
# 467 th data
# rnaNMUZpvvg[20]
# 0.27046796679496765
# positive
# Neutral
# 468 th data
# rnaNMUZpvvg[21]
# 0.2714690566062927
# positive
# Neutral
# 469 th data
# tIrG4oNLFzE[0]
# 0.2028263360261917
# positive
# Neutral
# 470 th data
# tIrG4oNLFzE[1]
# 0.30016669631004333
# positive
# Neutral
# 471 th data
# tIrG4oNLFzE[2]
# 0.12079089879989624
# positive
# Neutral
# 472 th data
# tIrG4oNLFzE[3]
# 0.21622301638126373
# positive
# Neutral
# 473 th data
# tIrG4oNLFzE[4]
# 0.23526863753795624
# positive
# Neutral
# 474 th data
# tIrG4oNLFzE[5]
# 0.26394426822662354
# positive
# Neutral
# 475 th data
# tIrG4oNLFzE[6]
# 0.23162169754505157
# positive
# Neutral
# 476 th data
# tIrG4oNLFzE[7]
# 0.27674421668052673
# positive
# Neutral
# 477 th data
# tIrG4oNLFzE[8]
# 0.258593887090683
# positive
# Neutral
# 478 th data
# tIrG4oNLFzE[9]
# 0.28837141394615173
# positive
# Neutral
# 479 th data
# tIrG4oNLFzE[10]
# 0.20109616219997406
# positive
# Neutral
# 480 th data
# tIrG4oNLFzE[11]
# 0.21635667979717255
# positive
# Neutral
# 481 th data
# tIrG4oNLFzE[12]
# 0.24782101809978485
# positive
# Neutral
# 482 th data
# tIrG4oNLFzE[13]
# 0.2105035036802292
# positive
# Neutral
# 483 th data
# tIrG4oNLFzE[14]
# 0.22104208171367645
# positive
# Neutral
# 484 th data
# tIrG4oNLFzE[15]
# 0.24728943407535553
# positive
# Neutral
# 485 th data
# tIrG4oNLFzE[16]
# 0.23413147032260895
# positive
# Neutral
# 486 th data
# tIrG4oNLFzE[17]
# 0.2253752201795578
# positive
# Neutral
# 487 th data
# tStelxIAHjw[0]
# 0.28602999448776245
# positive
# Neutral
# 488 th data
# tStelxIAHjw[1]
# 0.17171365022659302
# positive
# Neutral
# 489 th data
# tStelxIAHjw[2]
# 0.19042320549488068
# positive
# Neutral
# 490 th data
# tStelxIAHjw[3]
# 0.18290109932422638
# positive
# Neutral
# 491 th data
# tStelxIAHjw[4]
# 0.2745048403739929
# positive
# Neutral
# 492 th data
# tStelxIAHjw[5]
# 0.2588824927806854
# positive
# Neutral
# 493 th data
# tStelxIAHjw[6]
# 0.22076301276683807
# positive
# Neutral
# 494 th data
# tStelxIAHjw[7]
# 0.2846026122570038
# positive
# Neutral
# 495 th data
# tStelxIAHjw[8]
# 0.21433980762958527
# positive
# Neutral
# 496 th data
# tStelxIAHjw[9]
# 0.20040930807590485
# positive
# Neutral
# 497 th data
# tStelxIAHjw[10]
# 0.26285967230796814
# positive
# Neutral
# 498 th data
# tStelxIAHjw[11]
# 0.1942426562309265
# positive
# Neutral
# 499 th data
# tStelxIAHjw[12]
# 0.3094685971736908
# positive
# Neutral
# 500 th data
# tStelxIAHjw[13]
# 0.31693699955940247
# positive
# Neutral
# 501 th data
# tStelxIAHjw[14]
# 0.15966759622097015
# positive
# Neutral
# 502 th data
# tStelxIAHjw[15]
# 0.3743186891078949
# positive
# Neutral
# 503 th data
# tmZoasNr4rU[0]
# 0.25747957825660706
# positive
# Neutral
# 504 th data
# tmZoasNr4rU[1]
# 0.22269783914089203
# positive
# Neutral
# 505 th data
# tmZoasNr4rU[2]
# 0.2074209749698639
# positive
# Neutral
# 506 th data
# tmZoasNr4rU[3]
# 0.29426810145378113
# positive
# Neutral
# 507 th data
# tmZoasNr4rU[4]
# 0.38725873827934265
# positive
# Neutral
# 508 th data
# tmZoasNr4rU[5]
# 0.26292720437049866
# positive
# Neutral
# 509 th data
# tmZoasNr4rU[6]
# 0.17610275745391846
# positive
# Neutral
# 510 th data
# tmZoasNr4rU[7]
# 0.2901805341243744
# positive
# Neutral
# 511 th data
# tmZoasNr4rU[8]
# 0.2944613993167877
# positive
# Neutral
# 512 th data
# tmZoasNr4rU[9]
# 0.30910244584083557
# positive
# Neutral
# 513 th data
# tmZoasNr4rU[10]
# 0.24496586620807648
# positive
# Neutral
# 514 th data
# tmZoasNr4rU[11]
# 0.20015119016170502
# positive
# Neutral
# 515 th data
# tmZoasNr4rU[12]
# 0.16999663412570953
# positive
# Neutral
# 516 th data
# tmZoasNr4rU[13]
# 0.1991415172815323
# positive
# Neutral
# 517 th data
# tmZoasNr4rU[14]
# 0.24631144106388092
# positive
# Neutral
# 518 th data
# tmZoasNr4rU[15]
# 0.2602524161338806
# positive
# Neutral
# 519 th data
# tmZoasNr4rU[16]
# 0.2652356028556824
# positive
# Neutral
# 520 th data
# tmZoasNr4rU[17]
# 0.3258415162563324
# positive
# Neutral
# 521 th data
# tmZoasNr4rU[18]
# 0.1624239832162857
# positive
# Neutral
# 522 th data
# tmZoasNr4rU[19]
# 0.24641631543636322
# positive
# Neutral
# 523 th data
# v0zCBqDeKcE[0]
# 0.2738226354122162
# positive
# Neutral
# 524 th data
# v0zCBqDeKcE[1]
# 0.24378909170627594
# positive
# Neutral
# 525 th data
# v0zCBqDeKcE[2]
# 0.2158491164445877
# positive
# Neutral
# 526 th data
# v0zCBqDeKcE[3]
# 0.15624020993709564
# positive
# Neutral
# 527 th data
# v0zCBqDeKcE[4]
# 0.3569348454475403
# positive
# Neutral
# 528 th data
# v0zCBqDeKcE[5]
# 0.28311702609062195
# positive
# Neutral
# 529 th data
# v0zCBqDeKcE[6]
# 0.29888856410980225
# positive
# Neutral
# 530 th data
# v0zCBqDeKcE[7]
# 0.3007088601589203
# positive
# Neutral
# 531 th data
# v0zCBqDeKcE[8]
# 0.3396063446998596
# positive
# Neutral
# 532 th data
# v0zCBqDeKcE[9]
# 0.27831190824508667
# positive
# Neutral
# 533 th data
# v0zCBqDeKcE[10]
# 0.20564527809619904
# positive
# Neutral
# 534 th data
# v0zCBqDeKcE[11]
# 0.23086126148700714
# positive
# Neutral
# 535 th data
# v0zCBqDeKcE[12]
# 0.22536854445934296
# positive
# Neutral
# 536 th data
# v0zCBqDeKcE[13]
# 0.44210973381996155
# positive
# slightly positive
# 537 th data
# v0zCBqDeKcE[14]
# 0.2603906989097595
# positive
# Neutral
# 538 th data
# v0zCBqDeKcE[15]
# 0.19542181491851807
# positive
# Neutral
# 539 th data
# vvZ4IcEtiZc[0]
# 0.23929907381534576
# positive
# Neutral
# 540 th data
# vvZ4IcEtiZc[1]
# 0.19531695544719696
# positive
# Neutral
# 541 th data
# vvZ4IcEtiZc[2]
# 0.14986522495746613
# positive
# Neutral
# 542 th data
# vvZ4IcEtiZc[3]
# 0.2598690986633301
# positive
# Neutral
# 543 th data
# vvZ4IcEtiZc[4]
# 0.32016849517822266
# positive
# Neutral
# 544 th data
# vvZ4IcEtiZc[5]
# 0.2588259279727936
# positive
# Neutral
# 545 th data
# vvZ4IcEtiZc[6]
# 0.2057999223470688
# positive
# Neutral
# 546 th data
# vvZ4IcEtiZc[7]
# 0.20397235453128815
# positive
# Neutral
# 547 th data
# vvZ4IcEtiZc[8]
# 0.2641603648662567
# positive
# Neutral
# 548 th data
# vvZ4IcEtiZc[9]
# 0.2286638468503952
# positive
# Neutral
# 549 th data
# vvZ4IcEtiZc[10]
# 0.25955888628959656
# positive
# Neutral
# 550 th data
# vvZ4IcEtiZc[11]
# 0.14611953496932983
# positive
# Neutral
# 551 th data
# vyB00TXsimI[0]
# 0.3149382770061493
# positive
# Neutral
# 552 th data
# vyB00TXsimI[1]
# 0.2963070571422577
# positive
# Neutral
# 553 th data
# vyB00TXsimI[2]
# 0.2758033275604248
# positive
# Neutral
# 554 th data
# vyB00TXsimI[3]
# 0.28548577427864075
# positive
# Neutral
# 555 th data
# vyB00TXsimI[4]
# 0.25255152583122253
# positive
# Neutral
# 556 th data
# vyB00TXsimI[5]
# 0.2996255159378052
# positive
# Neutral
# 557 th data
# vyB00TXsimI[6]
# 0.3474065363407135
# positive
# Neutral
# 558 th data
# vyB00TXsimI[7]
# 0.2799510359764099
# positive
# Neutral
# 559 th data
# vyB00TXsimI[8]
# 0.24253417551517487
# positive
# Neutral
# 560 th data
# vyB00TXsimI[9]
# 0.23261912167072296
# positive
# Neutral
# 561 th data
# vyB00TXsimI[10]
# 0.2334597259759903
# positive
# Neutral
# 562 th data
# vyB00TXsimI[11]
# 0.31621694564819336
# positive
# Neutral
# 563 th data
# vyB00TXsimI[12]
# 0.2988171875476837
# positive
# Neutral
# 564 th data
# vyB00TXsimI[13]
# 0.3220843970775604
# positive
# Neutral
# 565 th data
# vyB00TXsimI[14]
# 0.23416762053966522
# positive
# Neutral
# 566 th data
# vyB00TXsimI[15]
# 0.32795247435569763
# positive
# Neutral
# 567 th data
# vyB00TXsimI[16]
# 0.2814044654369354
# positive
# Neutral
# 568 th data
# vyB00TXsimI[17]
# 0.2758951485157013
# positive
# Neutral
# 569 th data
# vyB00TXsimI[18]
# 0.16639213263988495
# positive
# Neutral
# 570 th data
# vyB00TXsimI[19]
# 0.26426902413368225
# positive
# Neutral
# 571 th data
# vyB00TXsimI[20]
# 0.3164202570915222
# positive
# Neutral
# 572 th data
# vyB00TXsimI[21]
# 0.24826665222644806
# positive
# Neutral
# 573 th data
# wMbj6ajWbic[0]
# 0.21683235466480255
# positive
# Neutral
# 574 th data
# wMbj6ajWbic[1]
# 0.24255169928073883
# positive
# Neutral
# 575 th data
# wMbj6ajWbic[2]
# 0.2377445548772812
# positive
# Neutral
# 576 th data
# wMbj6ajWbic[3]
# 0.12133297324180603
# positive
# Neutral
# 577 th data
# wMbj6ajWbic[4]
# 0.2647157609462738
# positive
# Neutral
# 578 th data
# wMbj6ajWbic[5]
# 0.2588140368461609
# positive
# Neutral
# 579 th data
# wMbj6ajWbic[6]
# 0.23293356597423553
# positive
# Neutral
# 580 th data
# wMbj6ajWbic[7]
# 0.2785012722015381
# positive
# Neutral
# 581 th data
# wMbj6ajWbic[8]
# 0.2031114250421524
# positive
# Neutral
# 582 th data
# wMbj6ajWbic[9]
# 0.2134527713060379
# positive
# Neutral
# 583 th data
# wMbj6ajWbic[10]
# 0.2996766269207001
# positive
# Neutral
# 584 th data
# wMbj6ajWbic[11]
# 0.25593599677085876
# positive
# Neutral
# 585 th data
# wMbj6ajWbic[12]
# 0.2098090797662735
# positive
# Neutral
# 586 th data
# wMbj6ajWbic[13]
# 0.26442691683769226
# positive
# Neutral
# 587 th data
# wMbj6ajWbic[14]
# 0.25857070088386536
# positive
# Neutral
# 588 th data
# wMbj6ajWbic[15]
# 0.24034367501735687
# positive
# Neutral
# 589 th data
# wMbj6ajWbic[16]
# 0.2444070726633072
# positive
# Neutral
# 590 th data
# wMbj6ajWbic[17]
# 0.23755325376987457
# positive
# Neutral
# 591 th data
# wMbj6ajWbic[18]
# 0.3689420521259308
# positive
# Neutral
# 592 th data
# wMbj6ajWbic[19]
# 0.24834324419498444
# positive
# Neutral
# 593 th data
# wMbj6ajWbic[20]
# 0.3349640667438507
# positive
# Neutral
# 594 th data
# wMbj6ajWbic[21]
# 0.2604638934135437
# positive
# Neutral
# 595 th data
# wMbj6ajWbic[22]
# 0.22085560858249664
# positive
# Neutral
# 596 th data
# wMbj6ajWbic[23]
# 0.26992473006248474
# positive
# Neutral
# 597 th data
# wMbj6ajWbic[24]
# 0.22985722124576569
# positive
# Neutral
# 598 th data
# wMbj6ajWbic[25]
# 0.2569415867328644
# positive
# Neutral
# 599 th data
# wMbj6ajWbic[26]
# 0.30151715874671936
# positive
# Neutral
# 600 th data
# wMbj6ajWbic[27]
# 0.2749559283256531
# positive
# Neutral
# 601 th data
# wMbj6ajWbic[28]
# 0.21554894745349884
# positive
# Neutral
# 602 th data
# wMbj6ajWbic[29]
# 0.29100942611694336
# positive
# Neutral
# 603 th data
# yDtzw_Y-7RU[0]
# 0.3146897256374359
# positive
# Neutral
# 604 th data
# yDtzw_Y-7RU[1]
# 0.24763937294483185
# positive
# Neutral
# 605 th data
# yDtzw_Y-7RU[2]
# 0.18077169358730316
# positive
# Neutral
# 606 th data
# yDtzw_Y-7RU[3]
# 0.20906932651996613
# positive
# Neutral
# 607 th data
# yDtzw_Y-7RU[4]
# 0.2759082019329071
# positive
# Neutral
# 608 th data
# yDtzw_Y-7RU[5]
# 0.2087361365556717
# positive
# Neutral
# 609 th data
# yDtzw_Y-7RU[6]
# 0.2896794378757477
# positive
# Neutral
# 610 th data
# yDtzw_Y-7RU[7]
# 0.26885583996772766
# positive
# Neutral
# 611 th data
# yDtzw_Y-7RU[8]
# 0.2122594267129898
# positive
# Neutral
# 612 th data
# yDtzw_Y-7RU[9]
# 0.1445305347442627
# positive
# Neutral
# 613 th data
# yDtzw_Y-7RU[10]
# 0.2667042315006256
# positive
# Neutral
# 614 th data
# yDtzw_Y-7RU[11]
# 0.17599548399448395
# positive
# Neutral
# 615 th data
# yDtzw_Y-7RU[12]
# 0.19935865700244904
# positive
# Neutral
# 616 th data
# yDtzw_Y-7RU[13]
# 0.2669738829135895
# positive
# Neutral
# 617 th data
# yDtzw_Y-7RU[14]
# 0.27535954117774963
# positive
# Neutral
# 618 th data
# yDtzw_Y-7RU[15]
# 0.20138835906982422
# positive
# Neutral
# 619 th data
# yDtzw_Y-7RU[16]
# 0.19818635284900665
# positive
# Neutral
# 620 th data
# yDtzw_Y-7RU[17]
# 0.2783823609352112
# positive
# Neutral
# 621 th data
# yDtzw_Y-7RU[18]
# 0.272556334733963
# positive
# Neutral
# 622 th data
# yDtzw_Y-7RU[19]
# 0.20136789977550507
# positive
# Neutral
# 623 th data
# yDtzw_Y-7RU[20]
# 0.2884316146373749
# positive
# Neutral
# 624 th data
# yDtzw_Y-7RU[21]
# 0.28133925795555115
# positive
# Neutral
# 625 th data
# yDtzw_Y-7RU[22]
# 0.15523314476013184
# positive
# Neutral
# 626 th data
# yDtzw_Y-7RU[23]
# 0.2662632167339325
# positive
# Neutral
# 627 th data
# yvsjCA6Y5Fc[0]
# 0.2504977285861969
# positive
# Neutral
# 628 th data
# yvsjCA6Y5Fc[1]
# 0.29524925351142883
# positive
# Neutral
# 629 th data
# yvsjCA6Y5Fc[2]
# 0.21372641623020172
# positive
# Neutral
# 630 th data
# yvsjCA6Y5Fc[3]
# 0.22152353823184967
# positive
# Neutral
# 631 th data
# yvsjCA6Y5Fc[4]
# 0.09590639173984528
# positive
# Neutral
# 632 th data
# yvsjCA6Y5Fc[5]
# 0.20576892793178558
# positive
# Neutral
# 633 th data
# yvsjCA6Y5Fc[6]
# 0.2981887757778168
# positive
# Neutral
# 634 th data
# yvsjCA6Y5Fc[7]
# 0.11135253310203552
# positive
# Neutral
# 635 th data
# yvsjCA6Y5Fc[8]
# 0.19696778059005737
# positive
# Neutral
# 636 th data
# yvsjCA6Y5Fc[9]
# 0.22203467786312103
# positive
# Neutral
# 637 th data
# yvsjCA6Y5Fc[10]
# 0.3462516963481903
# positive
# Neutral
# 638 th data
# yvsjCA6Y5Fc[11]
# 0.12103122472763062
# positive
# Neutral
# 639 th data
# yvsjCA6Y5Fc[12]
# 0.15777002274990082
# positive
# Neutral
# 640 th data
# yvsjCA6Y5Fc[13]
# 0.26203373074531555
# positive
# Neutral
# 641 th data
# yvsjCA6Y5Fc[14]
# 0.14387692511081696
# positive
# Neutral
# 642 th data
# yvsjCA6Y5Fc[15]
# 0.17322306334972382
# positive
# Neutral
# 643 th data
# yvsjCA6Y5Fc[16]
# 0.2412540167570114
# positive
# Neutral
# 644 th data
# yvsjCA6Y5Fc[17]
# 0.15886114537715912
# positive
# Neutral
# 645 th data
# yvsjCA6Y5Fc[18]
# 0.23748673498630524
# positive
# Neutral
# 646 th data
# yvsjCA6Y5Fc[19]
# 0.2190508097410202
# positive
# Neutral
# 647 th data
# yvsjCA6Y5Fc[20]
# 0.28445717692375183
# positive
# Neutral
# 648 th data
# yvsjCA6Y5Fc[21]
# 0.2891993224620819
# positive
# Neutral
# 649 th data
# yvsjCA6Y5Fc[22]
# 0.16627323627471924
# positive
# Neutral
# 650 th data
# zhpQhgha_KU[0]
# 0.19917194545269012
# positive
# Neutral
# 651 th data
# zhpQhgha_KU[1]
# 0.28086456656455994
# positive
# Neutral
# 652 th data
# zhpQhgha_KU[2]
# 0.25902029871940613
# positive
# Neutral
# 653 th data
# zhpQhgha_KU[3]
# 0.27974340319633484
# positive
# Neutral
# 654 th data
# zhpQhgha_KU[4]
# 0.11446148157119751
# positive
# Neutral
# 655 th data
# zhpQhgha_KU[5]
# 0.18339650332927704
# positive
# Neutral
# 656 th data
# zhpQhgha_KU[6]
# 0.29372185468673706
# positive
# Neutral
# 657 th data
# zhpQhgha_KU[7]
# 0.1526385396718979
# positive
# Neutral
# 658 th data
# zhpQhgha_KU[8]
# 0.28489306569099426
# positive
# Neutral
# 659 th data
# zhpQhgha_KU[9]
# 0.29520949721336365
# positive
# Neutral
# 660 th data
# zhpQhgha_KU[10]
# 0.2363216131925583
# positive
# Neutral
# 661 th data
# zhpQhgha_KU[11]
# 0.20980025827884674
# positive
# Neutral
# 662 th data
# zhpQhgha_KU[12]
# 0.2722696363925934
# positive
# Neutral
# 663 th data
# zhpQhgha_KU[13]
# 0.18861030042171478
# positive
# Neutral
# 664 th data
# zhpQhgha_KU[14]
# 0.13406069576740265
# positive
# Neutral
# 665 th data
# zhpQhgha_KU[15]
# 0.3314063847064972
# positive
# Neutral
# 666 th data
# zhpQhgha_KU[16]
# 0.2642911374568939
# positive
# Neutral
# 667 th data
# zhpQhgha_KU[17]
# 0.18216966092586517
# positive
# Neutral
# 668 th data
# zhpQhgha_KU[18]
# 0.13593702018260956
# positive
# Neutral
# 669 th data
# zhpQhgha_KU[19]
# 0.2082941085100174
# positive
# Neutral
# 670 th data
# zhpQhgha_KU[20]
# 0.1553269326686859
# positive
# Neutral
# 671 th data
# zhpQhgha_KU[21]
# 0.1830836683511734
# positive
# Neutral
# 672 th data
# zhpQhgha_KU[22]
# 0.1236572414636612
# positive
# Neutral
# 673 th data
# zhpQhgha_KU[23]
# 0.25545254349708557
# positive
# Neutral
# 674 th data
# zhpQhgha_KU[24]
# 0.17867884039878845
# positive
# Neutral
# 675 th data
# zhpQhgha_KU[25]
# 0.28903815150260925
# positive
# Neutral
# 676 th data
# zhpQhgha_KU[26]
# 0.22296027839183807
# positive
# Neutral
# 677 th data
# zhpQhgha_KU[27]
# 0.22303874790668488
# positive
# Neutral
# 678 th data
# zhpQhgha_KU[28]
# 0.1552189588546753
# positive
# Neutral
# 679 th data
# zhpQhgha_KU[29]
# 0.21375231444835663
# positive
# Neutral
# 680 th data
# zhpQhgha_KU[30]
# 0.2125142365694046
# positive
# Neutral
# 681 th data
# zhpQhgha_KU[31]
# 0.2334427684545517
# positive
# Neutral
# 682 th data
# zhpQhgha_KU[32]
# 0.29228052496910095
# positive
# Neutral
# 683 th data
# zhpQhgha_KU[33]
# 0.22896774113178253
# positive
# Neutral
# 684 th data
# zhpQhgha_KU[34]
# 0.1996588557958603
# positive
# Neutral

# %%
len(segment_list)
# Out:
# 685

# %%
import pickle
# Gold-truth
labels = []
labels_2 = []
labels_7 = []
with open(f"../../datasets/MOSI/mosi.pkl", "rb") as handle:
    data = pickle.load(handle)

test_data = data["test"]

video = set()
count = 0

for idx in range(len(test_data)):
    (words, visual, acoustic), label, segment = test_data[idx]
    # if args.dataset == 'mosi':
    assert segment_list[idx] == segment
    # else:
    #     video_name = segment[0]
    #     if video_name in video:
    #         count += 1
    #     else:
    #         video.add(video_name)
    #         count = 0
    #     assert segment_list[idx] == segment

    labels.append(label[0][0])

    # label_2 appending
    if label > 0:
        labels_2.append('positive')
    else:
        labels_2.append('negative')
    
    # label_7 appending
    if label < -15/7:
        labels_7.append('very negative')
    elif label < -9/7:
        labels_7.append('negative')
    elif label < -3/7:
        labels_7.append('slightly negative')
    elif label < 3/7:
        labels_7.append('Neutral')
    elif label < 9/7:
        labels_7.append('slightly positive')
    elif label < 15/7:
        labels_7.append('positive')
    else:
        labels_7.append('very positive')
count = 0

# %%
import plotly.express as px
import plotly.subplots as sp
import pandas as pd

d = {'segmentID': segment_list, 'labels': labels, 'labels_2': labels_2, 'labels_7': labels_7, 'preds': preds, 'preds_2': preds_2, 'preds_7': preds_7}
df = pd.DataFrame(data=d)
order = ['very negative', 'negative', 'slightly negative', 'Neutral', 'slightly positive', 'positive', 'very positive']

fig1 = px.bar(df, x="labels_7")
fig2 = px.bar(df, x="preds_7")

fig1_traces = []
fig2_traces = []

for trace in range(len(fig1["data"])):
    fig1_traces.append(fig1["data"][trace])
for trace in range(len(fig2["data"])):
    fig2_traces.append(fig2["data"][trace])

this_figure = sp.make_subplots(rows=1, cols=2, subplot_titles=("Gold", "MISA"))
for traces in fig1_traces:
    this_figure.append_trace(traces, row=1, col=1)
for traces in fig2_traces:
    this_figure.append_trace(traces, row=1, col=2)

# this_figure.update_layout(height=600, width=1500, title_text="CMU-MOSI 7 Class Sentiment Intensity")
this_figure.update_xaxes(categoryorder='array', categoryarray= order)
# this_figure.update_yaxes(range=[0,250])
this_figure.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-655eb2e7e283> in <module>
#       3 import pandas as pd
#       4
# ----> 5 d = {'segmentID': segment_list, 'labels': labels, 'labels_2': labels_2, 'labels_7': labels_7, 'preds': preds, 'preds_2': preds_2, 'preds_7': preds_7}
#       6 df = pd.DataFrame(data=d)
#       7 order = ['very negative', 'negative', 'slightly negative', 'Neutral', 'slightly positive', 'positive', 'very positive']
#
# NameError: name 'segment_list' is not defined
